# %%
import pandas as pd

# %%
poke = pd.read_csv("C:/Users/rajen/Data Analysis/pokemon.csv")

# %%
poke.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
poke_name = list(poke.name)

# %%
poke_name
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
letters = 'ni oq e  '
l= []

# %%
for word in poke_name:
    if len(letters) == len(word):
        l.append(word)

# %%
len(letters)
# Out:
# 9

# %%
l
# Out:
# ['Bulbasaur',
#  'Charizard',
#  'Wartortle',
#  'Blastoise',
#  'Pidgeotto',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoqueen',
#  'Ninetales',
#  'Vileplume',
#  'Growlithe',
#  'Poliwhirl',
#  'Poliwrath',
#  'Tentacool',
#  'Magnemite',
#  'Electrode',
#  'Exeggcute',
#  'Exeggutor',
#  'Hitmonlee',
#  'Lickitung',
#  'Dragonair',
#  'Dragonite',
#  'Chikorita',
#  'Cyndaquil',
#  'Igglybuff',
#  'Bellossom',
#  'Azumarill',
#  'Sudowoodo',
#  'Wobbuffet',
#  'Girafarig',
#  'Dunsparce',
#  'Heracross',
#  'Teddiursa',
#  'Piloswine',
#  'Octillery',
#  'Hitmontop',
#  'Tyranitar',
#  'Combusken',
#  'Marshtomp',
#  'Poochyena',
#  'Mightyena',
#  'Zigzagoon',
#  'Beautifly',
#  'Gardevoir',
#  'Shroomish',
#  'Electrike',
#  'Manectric',
#  'Crawdaunt',
#  'Relicanth',
#  'Salamence',
#  'Metagross',
#  'Registeel',
#  'Infernape',
#  'Staraptor',
#  'Kricketot',
#  'Rampardos',
#  'Bastiodon',
#  'Vespiquen',
#  'Pachirisu',
#  'Gastrodon',
#  'Mismagius',
#  'Honchkrow',
# ...
