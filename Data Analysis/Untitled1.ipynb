# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
games = pd.read_csv("C:/Users/rajen/Data Analysis/games_sales.csv")

# %%
games.head()
# Out:
#                              Name Platform    Year    Genre  \
# 0              Kinect Adventures!     X360  2010.0     Misc
# 1              Grand Theft Auto V      PS3  2013.0   Action
# 2              Grand Theft Auto V     X360  2013.0   Action
# 3  Call of Duty: Modern Warfare 3     X360  2011.0  Shooter
# 4         Call of Duty: Black Ops     X360  2010.0  Shooter
#
#                 Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 0  Microsoft Game Studios     14.97      4.94      0.24         1.67
# 1    Take-Two Interactive      7.01      9.27      0.97         4.14
# 2    Take-Two Interactive      9.63      5.31      0.06         1.38
# 3              Activision      9.03      4.28      0.13         1.32
# 4              Activision      9.67      3.73      0.11         1.13
#
#    Global_Sales
# 0         21.82
# 1         21.40
# 2         16.38
# 3         14.76
# 4         14.64

# %%
games.groupby('Platform').Global_Sales.sum().plot(kind='pie',figsize=(6,6));

# %%
sport_games = games[games.Genre == 'Sports'].loc[:,['Name','Platform','Global_Sales']].set_index('Name')

# %%
sport_games.head()
# Out:
#               Platform  Global_Sales
# Name
# FIFA 16            PS4          8.49
# FIFA 14            PS3          6.90
# FIFA 12            PS3          6.69
# FIFA 15            PS4          6.59
# Kinect Sports     X360          6.24

# %%
sport_games.sort_values(by='Global_Sales',ascending=False).head(20).plot(kind='bar',figsize=(15,7));

# %%
sport_games
# Out:
#                                         Platform  Global_Sales
# Name
# FIFA 16                                      PS4          8.49
# FIFA 14                                      PS3          6.90
# FIFA 12                                      PS3          6.69
# FIFA 15                                      PS4          6.59
# Kinect Sports                               X360          6.24
# ...                                          ...           ...
# WSC REAL 09: World Snooker Championship     X360          0.01
# World Snooker Championship 2007             X360          0.01
# Handball 16                                 X360          0.01
# LMA Manager 2007                            X360          0.01
# Rugby Challenge 3                           XOne          0.01
#
# [512 rows x 2 columns]

# %%
sport_games.groupby('Name').Global_Sales.sum().nlargest(20).plot(kind='bar',figsize=(15,6));

# %%
plt.style.use('ggplot')

# %%
popu = pd.read_html('https://en.wikipedia.org/wiki/List_of_European_countries_by_population',header = 1)

# %%
len(popu)
# Out:
# 2

# %%
popu[0]
# Out:
#    Country.mw-parser-output .nobold{font-weight:normal}(or territory)  \
# 0                                   Russia * [Note 1]
# 1                                            Turkey *
# 2                                           Germany *
# 3                                   France * [Note 2]
# 4                           United Kingdom * [Note 3]
# 5                                             Italy *
# 6                                             Spain *
# 7                                  Ukraine * [Note 4]
# 8                                            Poland *
# 9                                           Romania *
# 10                                       Kazakhstan *
# 11                                      Netherlands *
# 12                                          Belgium *
# 13                                           Greece *
# 14                                   Czech Republic *
# 15                                           Sweden *
# ...

# %%
df = popu[0].loc[:,['Country.mw-parser-output .nobold{font-weight:normal}(or territory)','Estimate']]

# %%
df.rename({'Country.mw-parser-output .nobold{font-weight:normal}(or territory)':'Country'},axis=1,inplace=True)

# %%
df
# Out:
#                       Country   Estimate
# 0           Russia * [Note 1]  147190000
# 1                    Turkey *   84680273
# 2                   Germany *   83237124
# 3           France * [Note 2]   67874000
# 4   United Kingdom * [Note 3]   66329000
# 5                     Italy *   58906742
# 6                     Spain *   47432805
# 7          Ukraine * [Note 4]   41130432
# 8                    Poland *   38014000
# 9                   Romania *   19186000
# 10               Kazakhstan *   19009600
# 11              Netherlands *   17675187
# 12                  Belgium *   11584008
# 13                   Greece *   10678632
# 14           Czech Republic *   10519913
# 15                   Sweden *   10475203
# 16                 Portugal *   10361800
# 17               Azerbaijan *   10164464
# 18                  Hungary *    9689010
# 19                  Belarus *    9255500
# 20                  Austria *    9027999
# 21              Switzerland *    8753933
# ...

# %%
df.Country.replace('\[Note \d+\]','',regex=True,inplace=True)

# %%
df.replace('\*','',regex=True,inplace=True)

# %%
df.set_index('Country').head(10).plot(kind='bar');

# %%
folks = pd.read_excel("C:/Users/rajen/Data Analysis/folks.xlsx")

# %%
folks
# Out:
#             name  salary           occupation
# 0   Brian Dogood   64000  Software Technician
# 1     Leah Bokeh   73200       Data Scientist
# 2  Mark Prescott   76400  Business Consultant
# 3   Jurgen Gupta   94300   Aerospace Engineer

# %%
folks = pd.read_excel("C:/Users/rajen/Data Analysis/folks.xlsx",1)

# %%
folks
# Out:
#             name            hobby
# 0   Brian Dogood          Fishing
# 1     Leah Bokeh    Skateboarding
# 2  Mark Prescott  Value Investing
# 3   Jurgen Gupta          Drawing

# %%
# !pip show openpyxl
# Out:
# Name: openpyxl
# Version: 3.0.9
# Summary: A Python library to read/write Excel 2010 xlsx/xlsm files
# Home-page: https://openpyxl.readthedocs.io
# Author: See AUTHORS
# Author-email: charlie.clark@clark-consulting.eu
# License: MIT
# Location: c:\users\rajen\anaconda3\lib\site-packages
# Requires: et-xmlfile
# Required-by:

# %%
pd.read_pickle("C:/Users/rajen/Data Analysis/portfolio/portfolio")
# Out:
#   ticker  shares  book_cost
# 0   AAPL     150     123.23
# 1  GOOGL      10    1100.00
# 2   AMGN     230     227.23
# 3    VET     200      14.24
# 4   TSLA     100     260.00
# 5     DX      40      20.01

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
positions = pd.read_html('https://www.andybek.com/traders/')[0]

# %%
positions
# Out:
#   TraderID    Instrument   Amount Trader Location
# 0   MCBIRN     02079K107   150000              EU
# 1    WISEA     1350Z74U5  6400000              EU
# 2    IACOP  GB00B3KJDQ49  2430000              US

# %%
traders = pd.read_json('https://gist.githubusercontent.com/sh7ata/05e584ba8b9572b4ef9506af71deff9c/raw/22b2599d3ac743dcd5bdcfcd5a79059037e82afa/trader-names.json')

# %%
traders
# Out:
#              names    alias  seniority
# 0  Shylah McBirney   MCBIRN  Executive
# 1       Allen Wise    WISEA  Executive
# 2    Iacopo Brivio    IACOP     Junior
# 3   Allison Carter  CARTERA  Mid-level

# %%
df2 = traders.merge(positions,left_on='alias',right_on='TraderID',how='outer')

# %%
df2.to_csv('C:/Users/rajen/Data Analysis/portfolio/port1.csv')

# %%
import pickle

# %%
out = open('C:/Users/rajen/Data Analysis/portfolio/pickled_port','wb')

# %%
pickle.dump(df2,out)

# %%
out.close()

# %%
df2.drop('alias',axis=1,inplace=True)
