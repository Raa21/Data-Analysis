# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
players = pd.read_csv("C:/Users/rajen/Data Analysis/soccer.csv")

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.market_value > 40
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
players[players.market_value > 40]
# Out:
#                   name               club  age position  position_cat  \
# 0       Alexis Sanchez            Arsenal   28       LW             1
# 1           Mesut Ozil            Arsenal   28       AM             1
# 96         Eden Hazard            Chelsea   26       LW             1
# 97         Diego Costa            Chelsea   28       CF             1
# 108     N%27Golo Kante            Chelsea   26       DM             2
# 218  Philippe Coutinho          Liverpool   25       AM             1
# 244    Kevin De Bruyne    Manchester+City   26       AM             1
# 245      Sergio Aguero    Manchester+City   29       CF             1
# 246    Raheem Sterling    Manchester+City   22       LW             1
# 264      Romelu Lukaku  Manchester+United   24       CF             1
# 267         Paul Pogba  Manchester+United   24       CM             2
# 380          Dele Alli          Tottenham   21       CM             2
# ...

# %%
players.position
# Out:
# 0      LW
# 1      AM
# 2      GK
# 3      RW
# 4      CB
#        ..
# 460    CM
# 461    LB
# 462    RB
# 463    CF
# 464    CF
# Name: position, Length: 465, dtype: object

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players.position.isin(['LB','CB','RB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 460    False
# 461     True
# 462     True
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
players[players.position.isin(['LB','CB','RB'])]
# Out:
#                   name      club  age position  position_cat  market_value  \
# 4    Laurent Koscielny   Arsenal   31       CB             3          22.0
# 5      Hector Bellerin   Arsenal   22       RB             3          30.0
# 7        Nacho Monreal   Arsenal   31       LB             3          13.0
# 8     Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 17    Gabriel Paulista   Arsenal   26       CB             3          13.0
# ..                 ...       ...  ...      ...           ...           ...
# 455    Aaron Cresswell  West+Ham   27       LB             3          12.0
# 458     Angelo Ogbonna  West+Ham   29       CB             3           9.0
# 459     Pablo Zabaleta  West+Ham   32       RB             3           7.0
# 461     Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462          Sam Byram  West+Ham   23       RB             3           4.5
#
# ...

# %%
players.market_value.between(40,50, inclusive='neither')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
players[players.market_value.between(40,50, inclusive='neither')]
# Out:
#                   name             club  age position  position_cat  \
# 218  Philippe Coutinho        Liverpool   25       AM             1
# 246    Raheem Sterling  Manchester+City   22       LW             1
# 380          Dele Alli        Tottenham   21       CM             2
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 218          45.0        2958        9.0  30.80%         171       3
# 246          45.0        2074        8.0   3.80%         149       1
# 380          45.0        4626        9.5  38.60%         225       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 218      Brazil            0        3       10         1            0
# 246     England            0        2       11         1            0
# 380     England            0        1       17         1            0

# %%
players[players.market_value.between(40,50, inclusive='both')]
# Out:
#                     name               club  age position  position_cat  \
# 1             Mesut Ozil            Arsenal   28       AM             1
# 31   Alexandre Lacazette            Arsenal   26       CF             1
# 97           Diego Costa            Chelsea   28       CF             1
# 102     Thibaut Courtois            Chelsea   25       GK             4
# 108       N%27Golo Kante            Chelsea   26       DM             2
# 218    Philippe Coutinho          Liverpool   25       AM             1
# 219           Sadio Mane          Liverpool   25       LW             1
# 246      Raheem Sterling    Manchester+City   22       LW             1
# 263       Bernardo Silva    Manchester+City   22       RW             1
# 264        Romelu Lukaku  Manchester+United   24       CF             1
# 265         David de Gea  Manchester+United   26       GK             4
# 380            Dele Alli          Tottenham   21       CM             2
# ...

# %%
players.age <= 25
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460     True
# 461     True
# 462     True
# 463     True
# 464    False
# Name: age, Length: 465, dtype: bool

# %%
players[players.age <= 25]
# Out:
#                     name      club  age position  position_cat  market_value  \
# 5        Hector Bellerin   Arsenal   22       RB             3          30.0
# 8       Shkodran Mustafi   Arsenal   25       CB             3          30.0
# 9             Alex Iwobi   Arsenal   21       LW             1          10.0
# 10          Granit Xhaka   Arsenal   24       DM             2          35.0
# 11          Granit Xhaka   Arsenal   24       DM             2          35.0
# ..                   ...       ...  ...      ...           ...           ...
# 456         Pedro Obiang  West+Ham   25       CM             2           9.0
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
#
# ...

# %%
players.position.isin(['LB'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461     True
# 462    False
# 463    False
# 464    False
# Name: position, Length: 465, dtype: bool

# %%
players[(players.position.isin(['LB'])) & (players.age <= 25)]
# Out:
#                  name               club  age position  position_cat  \
# 29     Sead Kolasinac            Arsenal   24       LB             3
# 54         Brad Smith        Bournemouth   23       LB             3
# 112            Kenedy            Chelsea   21       LB             3
# 128   Jeffrey Schlupp     Crystal+Palace   24       LB             3
# 212      Ben Chilwell     Leicester+City   20       LB             3
# 236    Alberto Moreno          Liverpool   25       LB             3
# 281         Luke Shaw  Manchester+United   22       LB             3
# 294      Paul Dummett   Newcastle+United   25       LB             3
# 298  Massadio Haidara   Newcastle+United   24       LB             3
# 328      Matt Targett        Southampton   21       LB             3
# 354        Josh Tymon         Stoke+City   18       LB             3
# 369  Stephen Kingsley            Swansea   22       LB             3
# 389        Ben Davies          Tottenham   24       LB             3
# ...

# %%
players[players.position.isin(['LB'])]
# Out:
#                       name               club  age position  position_cat  \
# 7            Nacho Monreal            Arsenal   31       LB             3
# 18            Kieran Gibbs            Arsenal   27       LB             3
# 29          Sead Kolasinac            Arsenal   24       LB             3
# 34         Charlie Daniels        Bournemouth   30       LB             3
# 54              Brad Smith        Bournemouth   23       LB             3
# 62             Gaetan Bong  Brighton+and+Hove   29       LB             3
# 65          Markus Suttner  Brighton+and+Hove   30       LB             3
# 82            Stephen Ward            Burnley   31       LB             3
# 99   Marcos Alonso Mendoza            Chelsea   26       LB             3
# 112                 Kenedy            Chelsea   21       LB             3
# 119    Patrick van Aanholt     Crystal+Palace   26       LB             3
# 128        Jeffrey Schlupp     Crystal+Palace   24       LB             3
# ...

# %%
players[(players.position.isin(['LB'])) & (players.age <= 25) & (players.market_value >= 10)]
# Out:
#                name               club  age position  position_cat  \
# 29   Sead Kolasinac            Arsenal   24       LB             3
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
# 389      Ben Davies          Tottenham   24       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 29           15.0         618        6.0   6.90%           0       2
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
# 389          12.0         396        5.5   1.80%          90       2
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 29       Bosnia            1        2        1         1            0
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0
# ...

# %%
players[(players.position.isin(['LB'])) & 
        (players.age <= 25) &
        (players.market_value >= 10) &
        ~(players.club.isin(['Arsenal','Tottenham']))
       ]
# Out:
#                name               club  age position  position_cat  \
# 236  Alberto Moreno          Liverpool   25       LB             3
# 281       Luke Shaw  Manchester+United   22       LB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 236          10.0         397        4.5   0.30%           8       2
# 281          20.0         947        5.0   0.40%          45       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 236       Spain            0        3       10         1            0
# 281     England            0        2       12         1            0

# %%
arsenal_players = players.club == 'Arsenal'

# %%
arsenal_rb = players[arsenal_players].position == 'RB'

# %%
arsenal_rb
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5      True
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27     True
# 28    False
# 29    False
# 30    False
# 31    False
# Name: position, dtype: bool

# %%
p = players[arsenal_players]

# %%
p[arsenal_rb]
# Out:
#                name     club  age position  position_cat  market_value  \
# 5   Hector Bellerin  Arsenal   22       RB             3          30.0
# 27   Carl Jenkinson  Arsenal   25       RB             3           5.0
#
#     page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 5         1675        6.0  13.70%         119       2       Spain
# 27         561        4.5   0.40%           2       1     England
#
#     new_foreign  age_cat  club_id  big_club  new_signing
# 5             0        2        1         1            0
# 27            0        3        1         1            0

# %%
chelsea_players = players.club == 'Chelsea'

# %%
chel = players[chelsea_players]

# %%
pos = chel.position == 'GK'

# %%
chel[pos]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 102  Thibaut Courtois  Chelsea   25       GK             4          40.0
# 109   Willy Caballero  Chelsea   35       GK             4           1.5
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 102        1260        5.5  18.50%         141       2     Belgium
# 109         542        5.0   0.20%          64       3   Argentina
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 102            0        3        5         1            0
# 109            0        6        5         1            0

# %%
national = players.nationality == 'England'

# %%
national
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 460    False
# 461    False
# 462     True
# 463     True
# 464    False
# Name: nationality, Length: 465, dtype: bool

# %%
m = players.market_value.mean()

# %%
m
# Out:
# 11.125649350649349

# %%
val = players.market_value > m*2

# %%
val
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: market_value, Length: 465, dtype: bool

# %%
views = players.page_views > 4000

# %%
n_sig  = players.new_signing == 1

# %%
n_con = views ^ n_sig

# %%
players[national & val & n_con]
# Out:
#             name             club  age position  position_cat  market_value  \
# 256  John Stones  Manchester+City   23       CB             3          35.0
# 380    Dele Alli        Tottenham   21       CM             2          45.0
# 381   Harry Kane        Tottenham   23       CF             1          60.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 256        1078        5.5   2.30%          59       1     England
# 380        4626        9.5  38.60%         225       1     England
# 381        4161       12.5  35.10%         224       1     England
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 256            0        2       11         1            1
# 380            0        1       17         1            0
# 381            0        2       17         1            0

# %%
chelsea_pl = players.club == 'Chelsea'

# %%
chelsea_pl
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: club, Length: 465, dtype: bool

# %%
young = players.age <= 23

# %%
players[chelsea_pl & young]
# Out:
#                  name     club  age position  position_cat  market_value  \
# 110   Michy Batshuayi  Chelsea   23       CF             1          25.0
# 111        Kurt Zouma  Chelsea   22       CB             3          15.0
# 112            Kenedy  Chelsea   21       LB             3           7.0
# 115  Tiemoue Bakayoko  Chelsea   22       DM             2          16.0
#
#      page_views  fpl_value fpl_sel  fpl_points  region nationality  \
# 110        1162        8.5   1.60%          48       2     Belgium
# 111         723        5.5   0.80%          15       2      France
# 112         566        5.0   0.10%           3       3      Brazil
# 115        1011        5.0   1.60%           0       2      France
#
#      new_foreign  age_cat  club_id  big_club  new_signing
# 110            0        2        5         1            1
# 111            0        2        5         1            0
# 112            0        1        5         1            0
# ...

# %%
players.loc[chelsea_pl & young, ['name','position','market_value']]
# Out:
#                  name position  market_value
# 110   Michy Batshuayi       CF          25.0
# 111        Kurt Zouma       CB          15.0
# 112            Kenedy       LB           7.0
# 115  Tiemoue Bakayoko       DM          16.0

# %%
p_cols = players.columns.str.startswith('p')
p_cols
# Out:
# array([False, False, False,  True,  True, False,  True, False, False,
#        False, False, False, False, False, False, False, False])

# %%
players.loc[chelsea_pl & young, p_cols]
# Out:
#     position  position_cat  page_views
# 110       CF             1        1162
# 111       CB             3         723
# 112       LB             3         566
# 115       DM             2        1011

# %%
players.name
# Out:
# 0           Alexis Sanchez
# 1               Mesut Ozil
# 2                Petr Cech
# 3             Theo Walcott
# 4        Laurent Koscielny
#               ...
# 460    Edimilson Fernandes
# 461         Arthur Masuaku
# 462              Sam Byram
# 463        Ashley Fletcher
# 464           Diafra Sakho
# Name: name, Length: 465, dtype: object

# %%
pl_name = ['Theo Walcott','Mesut Ozil','Alexis Sanchez']

# %%
attri = ['age','position','market_value']

# %%
players.set_index('name').melt(pl_name,attri)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 players.set_index('name').melt(pl_name,attri)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:8434, in DataFrame.melt(self, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#    8423 @Appender(_shared_docs["melt"] % {"caller": "df.melt(", "other": "melt"})
#    8424 def melt(
#    8425     self,
#    (...)
#    8431     ignore_index: bool = True,
#    8432 ) -> DataFrame:
# -> 8434     return melt(
#    8435         self,
#    8436         id_vars=id_vars,
#    8437         value_vars=value_vars,
#    8438         var_name=var_name,
#    8439         value_name=value_name,
#    8440         col_level=col_level,
#    8441         ignore_index=ignore_index,
#    8442     )
#
# ...

# %%
ply = players.set_index('name')

# %%
ply
# Out:
#                          club  age position  position_cat  market_value  \
# name
# Alexis Sanchez        Arsenal   28       LW             1          65.0
# Mesut Ozil            Arsenal   28       AM             1          50.0
# Petr Cech             Arsenal   35       GK             4           7.0
# Theo Walcott          Arsenal   28       RW             1          20.0
# Laurent Koscielny     Arsenal   31       CB             3          22.0
# ...                       ...  ...      ...           ...           ...
# Edimilson Fernandes  West+Ham   21       CM             2           5.0
# Arthur Masuaku       West+Ham   23       LB             3           7.0
# Sam Byram            West+Ham   23       RB             3           4.5
# Ashley Fletcher      West+Ham   21       CF             1           1.0
# Diafra Sakho         West+Ham   27       CF             1          10.0
#
#                      page_views  fpl_value fpl_sel  fpl_points  region  \
# name
# ...

# %%
ply.index
# Out:
# Index(['Alexis Sanchez', 'Mesut Ozil', 'Petr Cech', 'Theo Walcott',
#        'Laurent Koscielny', 'Hector Bellerin', 'Olivier Giroud',
#        'Nacho Monreal', 'Shkodran Mustafi', 'Alex Iwobi',
#        ...
#        'Aaron Cresswell', 'Pedro Obiang', 'Sofiane Feghouli', 'Angelo Ogbonna',
#        'Pablo Zabaleta', 'Edimilson Fernandes', 'Arthur Masuaku', 'Sam Byram',
#        'Ashley Fletcher', 'Diafra Sakho'],
#       dtype='object', name='name', length=465)

# %%
ply.loc[pl_name,attri]
# Out:
#                 age position  market_value
# name
# Theo Walcott     28       RW          20.0
# Mesut Ozil       28       AM          50.0
# Alexis Sanchez   28       LW          65.0

# %%
players.sort_values('market_value',ascending =False)
# Out:
#                     name               club  age position  position_cat  \
# 96           Eden Hazard            Chelsea   26       LW             1
# 267           Paul Pogba  Manchester+United   24       CM             2
# 0         Alexis Sanchez            Arsenal   28       LW             1
# 244      Kevin De Bruyne    Manchester+City   26       AM             1
# 245        Sergio Aguero    Manchester+City   29       CF             1
# ..                   ...                ...  ...      ...           ...
# 287  Joel Castro Pereira  Manchester+United   21       GK             4
# 113     Eduardo Carvalho            Chelsea   34       LW             1
# 30          Granit Xhaka            Arsenal   24      NaN             2
# 192         Steve Mounie       Huddersfield   22       CF             1
# 195    Kasper Schmeichel     Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# ...

# %%
ply.sort_index(inplace =True)

# %%
ply
# Out:
#                               club  age position  position_cat  market_value  \
# name
# Aaron Cresswell           West+Ham   27       LB             3          12.0
# Aaron Lennon               Everton   30       RW             1           5.0
# Aaron Mooy            Huddersfield   26       CM             2           5.0
# Aaron Ramsey               Arsenal   26       CM             2          35.0
# Abdoulaye Doucoure         Watford   24       CM             2           6.0
# ...                            ...  ...      ...           ...           ...
# Yohan Cabaye        Crystal+Palace   31       CM             2          15.0
# YounÃ¨s Kaboul             Watford   31       CB             3           2.5
# Ã‰tienne Capoue            Watford   29       DM             2           9.0
# Ã€ngel Rangel              Swansea   34       RB             3           1.0
# Åukasz FabiaÅ„ski         Swansea   32       GK             4           9.0
#
# ...

# %%
ply.reset_index()
# Out:
#                    name            club  age position  position_cat  \
# 0       Aaron Cresswell        West+Ham   27       LB             3
# 1          Aaron Lennon         Everton   30       RW             1
# 2            Aaron Mooy    Huddersfield   26       CM             2
# 3          Aaron Ramsey         Arsenal   26       CM             2
# 4    Abdoulaye Doucoure         Watford   24       CM             2
# ..                  ...             ...  ...      ...           ...
# 460        Yohan Cabaye  Crystal+Palace   31       CM             2
# 461      YounÃ¨s Kaboul         Watford   31       CB             3
# 462     Ã‰tienne Capoue         Watford   29       DM             2
# 463       Ã€ngel Rangel         Swansea   34       RB             3
# 464  Åukasz FabiaÅ„ski         Swansea   32       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 0            12.0         380        5.0   1.30%          60       1
# ...

# %%
players.head()
# Out:
#                 name     club  age position  position_cat  market_value  \
# 0     Alexis Sanchez  Arsenal   28       LW             1          65.0
# 1         Mesut Ozil  Arsenal   28       AM             1          50.0
# 2          Petr Cech  Arsenal   35       GK             4           7.0
# 3       Theo Walcott  Arsenal   28       RW             1          20.0
# 4  Laurent Koscielny  Arsenal   31       CB             3          22.0
#
#    page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# 0        4329       12.0  17.10%         264       3           Chile
# 1        4395        9.5   5.60%         167       2         Germany
# 2        1529        5.5   5.90%         134       2  Czech Republic
# 3        2393        7.5   1.50%         122       1         England
# 4         912        6.0   0.70%         121       2          France
#
#    new_foreign  age_cat  club_id  big_club  new_signing
# 0            0        4        1         1            0
# ...

# %%
players.reindex(index=[0,1,2,3],columns = ['age','name','market_value'])
# Out:
#    age            name  market_value
# 0   28  Alexis Sanchez          65.0
# 1   28      Mesut Ozil          50.0
# 2   35       Petr Cech           7.0
# 3   28    Theo Walcott          20.0

# %%
list(players.columns.sort_values())
# Out:
# ['age',
#  'age_cat',
#  'big_club',
#  'club',
#  'club_id',
#  'fpl_points',
#  'fpl_sel',
#  'fpl_value',
#  'market_value',
#  'name',
#  'nationality',
#  'new_foreign',
#  'new_signing',
#  'page_views',
#  'position',
#  'position_cat',
#  'region']

# %%
players.reindex(index = [0,4,5,6,7], columns = list(players.columns.sort_values())[:6])
# Out:
#    age  age_cat  big_club     club  club_id  fpl_points
# 0   28        4         1  Arsenal        1         264
# 4   31        4         1  Arsenal        1         121
# 5   22        2         1  Arsenal        1         119
# 6   30        4         1  Arsenal        1         116
# 7   31        4         1  Arsenal        1         115

# %%
players.age.sort_values()
# Out:
# 237    17
# 354    18
# 439    18
# 235    18
# 274    19
#        ..
# 340    36
# 150    36
# 35     37
# 424    37
# 136    38
# Name: age, Length: 465, dtype: int64

# %%
players.loc[players.age.idxmin()]
# Out:
# name            Ben Woodburn
# club               Liverpool
# age                       17
# position                  LW
# position_cat               1
# market_value             1.5
# page_views              1241
# fpl_value                4.5
# fpl_sel                0.10%
# fpl_points                 5
# region                     1
# nationality            Wales
# new_foreign                0
# age_cat                    1
# club_id                   10
# big_club                   1
# new_signing                0
# Name: 237, dtype: object

# %%
new  = players.set_index('club')

# %%
new.sort_index()
# Out:
#                          name  age position  position_cat  market_value  \
# club
# Arsenal        Alexis Sanchez   28       LW             1          65.0
# Arsenal            Mesut Ozil   28       AM             1          50.0
# Arsenal             Petr Cech   35       GK             4           7.0
# Arsenal          Theo Walcott   28       RW             1          20.0
# Arsenal     Laurent Koscielny   31       CB             3          22.0
# ...                       ...  ...      ...           ...           ...
# West+Ham  Edimilson Fernandes   21       CM             2           5.0
# West+Ham       Arthur Masuaku   23       LB             3           7.0
# West+Ham            Sam Byram   23       RB             3           4.5
# West+Ham      Ashley Fletcher   21       CF             1           1.0
# West+Ham         Diafra Sakho   27       CF             1          10.0
#
#           page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# club
# ...

# %%
new
# Out:
#                          name  age position  position_cat  market_value  \
# club
# Arsenal        Alexis Sanchez   28       LW             1          65.0
# Arsenal            Mesut Ozil   28       AM             1          50.0
# Arsenal             Petr Cech   35       GK             4           7.0
# Arsenal          Theo Walcott   28       RW             1          20.0
# Arsenal     Laurent Koscielny   31       CB             3          22.0
# ...                       ...  ...      ...           ...           ...
# West+Ham  Edimilson Fernandes   21       CM             2           5.0
# West+Ham       Arthur Masuaku   23       LB             3           7.0
# West+Ham            Sam Byram   23       RB             3           4.5
# West+Ham      Ashley Fletcher   21       CF             1           1.0
# West+Ham         Diafra Sakho   27       CF             1          10.0
#
#           page_views  fpl_value fpl_sel  fpl_points  region     nationality  \
# club
# ...

# %%
new.sort_values('market_value',ascending =False)
# Out:
#                                   name  age position  position_cat  \
# club
# Chelsea                    Eden Hazard   26       LW             1
# Manchester+United           Paul Pogba   24       CM             2
# Arsenal                 Alexis Sanchez   28       LW             1
# Manchester+City        Kevin De Bruyne   26       AM             1
# Manchester+City          Sergio Aguero   29       CF             1
# ...                                ...  ...      ...           ...
# Manchester+United  Joel Castro Pereira   21       GK             4
# Chelsea               Eduardo Carvalho   34       LW             1
# Arsenal                   Granit Xhaka   24      NaN             2
# Huddersfield              Steve Mounie   22       CF             1
# Leicester+City       Kasper Schmeichel   30       GK             4
#
#                    market_value  page_views  fpl_value fpl_sel  fpl_points  \
# club
# ...

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
new.sort_index().sort_values('market_value',ascending = False)
# Out:
#                                   name  age position  position_cat  \
# club
# Chelsea                    Eden Hazard   26       LW             1
# Manchester+United           Paul Pogba   24       CM             2
# Arsenal                 Alexis Sanchez   28       LW             1
# Manchester+City        Kevin De Bruyne   26       AM             1
# Manchester+City          Sergio Aguero   29       CF             1
# ...                                ...  ...      ...           ...
# Manchester+United  Joel Castro Pereira   21       GK             4
# Chelsea               Eduardo Carvalho   34       LW             1
# Arsenal                   Granit Xhaka   24      NaN             2
# Huddersfield              Steve Mounie   22       CF             1
# Leicester+City       Kasper Schmeichel   30       GK             4
#
#                    market_value  page_views  fpl_value fpl_sel  fpl_points  \
# club
# ...

# %%
new.sort_values(by=['club','market_value'],ascending=[True,False])
# Out:
#                          name  age position  position_cat  market_value  \
# club
# Arsenal        Alexis Sanchez   28       LW             1          65.0
# Arsenal            Mesut Ozil   28       AM             1          50.0
# Arsenal   Alexandre Lacazette   26       CF             1          40.0
# Arsenal          Granit Xhaka   24       DM             2          35.0
# Arsenal          Granit Xhaka   24       DM             2          35.0
# ...                       ...  ...      ...           ...           ...
# West+Ham  Edimilson Fernandes   21       CM             2           5.0
# West+Ham            Sam Byram   23       RB             3           4.5
# West+Ham      Darren Randolph   30       GK             4           2.5
# West+Ham        James Collins   33       CB             3           2.0
# West+Ham      Ashley Fletcher   21       CF             1           1.0
#
#           page_views  fpl_value fpl_sel  fpl_points  region  nationality  \
# club
# ...

# %%
players.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Length: 465, dtype: bool

# %%
players[players.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
players[players.duplicated(subset=['club','age','market_value','position'],keep='last')]
# Out:
#                         name               club  age position  position_cat  \
# 10              Granit Xhaka            Arsenal   24       DM             2
# 12   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 13   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 58                Lewis Dunk  Brighton+and+Hove   25       CB             3
# 253              Fernandinho    Manchester+City   32       DM             2
# 273              Marcos Rojo  Manchester+United   27       CB             3
# 292             Ciaran Clark   Newcastle+United   27       CB             3
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 10           35.0        1815        5.5   2.00%          85       2
# 12           22.0        1519        6.0   1.80%          83       1
# 13           22.0        1519        6.0   1.80%          83       1
# 58            5.0         140        4.5   4.10%           0       1
# ...

# %%
players[players.duplicated(subset=['club','age','market_value','position'],keep=False)]
# Out:
#                         name               club  age position  position_cat  \
# 10              Granit Xhaka            Arsenal   24       DM             2
# 11              Granit Xhaka            Arsenal   24       DM             2
# 12   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 13   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 23   Alex Oxlade-Chamberlain            Arsenal   23       RM             2
# 58                Lewis Dunk  Brighton+and+Hove   25       CB             3
# 59               Shane Duffy  Brighton+and+Hove   25       CB             3
# 253              Fernandinho    Manchester+City   32       DM             2
# 260                 Fernando    Manchester+City   32       DM             2
# 273              Marcos Rojo  Manchester+United   27       CB             3
# 279           Chris Smalling  Manchester+United   27       CB             3
# ...

# %%
players[players.duplicated(subset = ['name','age'],keep='last')]
# Out:
#                        name     club  age position  position_cat  \
# 10             Granit Xhaka  Arsenal   24       DM             2
# 11             Granit Xhaka  Arsenal   24       DM             2
# 12  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 10          35.0        1815        5.5   2.00%          85       2
# 11          35.0        1815        5.5   2.00%          85       2
# 12          22.0        1519        6.0   1.80%          83       1
# 13          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 10  Switzerland            0        2        1         1            0
# 11  Switzerland            0        2        1         1            0
# 12      England            0        2        1         1            0
# ...

# %%
players.drop_duplicates().market_value.mean()
# Out:
# 11.026252723311545

# %%
players.market_value.mean()
# Out:
# 11.125649350649349

# %%
 players[players.duplicated()]
# Out:
#                        name     club  age position  position_cat  \
# 11             Granit Xhaka  Arsenal   24       DM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 23  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
#
#     market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 11          35.0        1815        5.5   2.00%          85       2
# 13          22.0        1519        6.0   1.80%          83       1
# 23          22.0        1519        6.0   1.80%          83       1
#
#     nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 11  Switzerland            0        2        1         1            0
# 13      England            0        2        1         1            0
# 23      England            0        2        1         1            0

# %%
players.drop(labels = 11, axis = 0).head(20)
# Out:
#                        name     club  age position  position_cat  \
# 0            Alexis Sanchez  Arsenal   28       LW             1
# 1                Mesut Ozil  Arsenal   28       AM             1
# 2                 Petr Cech  Arsenal   35       GK             4
# 3              Theo Walcott  Arsenal   28       RW             1
# 4         Laurent Koscielny  Arsenal   31       CB             3
# 5           Hector Bellerin  Arsenal   22       RB             3
# 6            Olivier Giroud  Arsenal   30       CF             1
# 7             Nacho Monreal  Arsenal   31       LB             3
# 8          Shkodran Mustafi  Arsenal   25       CB             3
# 9                Alex Iwobi  Arsenal   21       LW             1
# 10             Granit Xhaka  Arsenal   24       DM             2
# 12  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# 13  Alex Oxlade-Chamberlain  Arsenal   23       RM             2
# ...

# %%
players.drop(labels=['position_cat','region'],axis=1)
# Out:
#                     name      club  age position  market_value  page_views  \
# 0         Alexis Sanchez   Arsenal   28       LW          65.0        4329
# 1             Mesut Ozil   Arsenal   28       AM          50.0        4395
# 2              Petr Cech   Arsenal   35       GK           7.0        1529
# 3           Theo Walcott   Arsenal   28       RW          20.0        2393
# 4      Laurent Koscielny   Arsenal   31       CB          22.0         912
# ..                   ...       ...  ...      ...           ...         ...
# 460  Edimilson Fernandes  West+Ham   21       CM           5.0         288
# 461       Arthur Masuaku  West+Ham   23       LB           7.0         199
# 462            Sam Byram  West+Ham   23       RB           4.5         198
# 463      Ashley Fletcher  West+Ham   21       CF           1.0         412
# 464         Diafra Sakho  West+Ham   27       CF          10.0         214
#
# ...

# %%
players.shape
# Out:
# (465, 17)

# %%
ages = players.age

# %%
ages[ages.isna()]
# Out:
# Series([], Name: age, dtype: int64)

# %%
players[ages.isna()]
# Out:
# Empty DataFrame
# Columns: [name, club, age, position, position_cat, market_value, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %%
players.isna()
# Out:
#       name   club    age  position  position_cat  market_value  page_views  \
# 0    False  False  False     False         False         False       False
# 1    False  False  False     False         False         False       False
# 2    False  False  False     False         False         False       False
# 3    False  False  False     False         False         False       False
# 4    False  False  False     False         False         False       False
# ..     ...    ...    ...       ...           ...           ...         ...
# 460  False  False  False     False         False         False       False
# 461  False  False  False     False         False         False       False
# 462  False  False  False     False         False         False       False
# 463  False  False  False     False         False         False       False
# 464  False  False  False     False         False         False       False
#
# ...

# %%
players[players.isna().values]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 30   Switzerland            0        2        1         1            0
# ...

# %%
players[players.isna().values].drop_duplicates()
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24      NaN             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30            NaN        1815        5.5   2.00%          85       2
# 192           NaN          56        6.0   0.60%           0       2
# 195           NaN        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0

# %%
players.fillna('something important').loc[[30,192,195]]
# Out:
#                   name            club  age             position  \
# 30        Granit Xhaka         Arsenal   24  something important
# 192       Steve Mounie    Huddersfield   22                   CF
# 195  Kasper Schmeichel  Leicester+City   30                   GK
#
#      position_cat         market_value  page_views  fpl_value fpl_sel  \
# 30              2  something important        1815        5.5   2.00%
# 192             1  something important          56        6.0   0.60%
# 195             4  something important        1601        5.0   2.40%
#
#      fpl_points  region  nationality  new_foreign  age_cat  club_id  big_club  \
# 30           85       2  Switzerland            0        2        1         1
# 192           0       2        Benin            0        2        8         0
# 195         109       2      Denmark            0        4        9         0
#
#      new_signing
# 30             0
# 192            0
# 195            0

# %%
players.fillna({
    'position':'RM',
    'market_value':100
}).loc[[30,192,195]]
# Out:
#                   name            club  age position  position_cat  \
# 30        Granit Xhaka         Arsenal   24       RM             2
# 192       Steve Mounie    Huddersfield   22       CF             1
# 195  Kasper Schmeichel  Leicester+City   30       GK             4
#
#      market_value  page_views  fpl_value fpl_sel  fpl_points  region  \
# 30          100.0        1815        5.5   2.00%          85       2
# 192         100.0          56        6.0   0.60%           0       2
# 195         100.0        1601        5.0   2.40%         109       2
#
#      nationality  new_foreign  age_cat  club_id  big_club  new_signing
# 30   Switzerland            0        2        1         1            0
# 192        Benin            0        2        8         0            0
# 195      Denmark            0        4        9         0            0
