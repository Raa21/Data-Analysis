# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
attack =  pd.read_csv("C:/Users/rajen/Data Analysis/UCL 2021-22 data analysis/attacking.csv")
attempt = pd.read_csv("C:/Users/rajen/Data Analysis/UCL 2021-22 data analysis/attempts.csv")
defend =  pd.read_csv("C:/Users/rajen/Data Analysis/UCL 2021-22 data analysis/defending.csv")
disc = pd.read_csv("C:/Users/rajen/Data Analysis/UCL 2021-22 data analysis/disciplinary.csv")
distri = pd.read_csv("C:/Users/rajen/Data Analysis/UCL 2021-22 data analysis/distributon.csv")
goalkeep = pd.read_csv("C:/Users/rajen/Data Analysis/UCL 2021-22 data analysis/goalkeeping.csv")
goal = pd.read_csv("C:/Users/rajen/Data Analysis/UCL 2021-22 data analysis/goals.csv")
stats =  pd.read_csv("C:/Users/rajen/Data Analysis/UCL 2021-22 data analysis/key_stats.csv")

# %%
attack.head()
# Out:
#    serial       player_name         club    position  assists  corner_taken  \
# 0       1   Bruno Fernandes  Man. United  Midfielder        7            10
# 1       2   Vinícius Júnior  Real Madrid     Forward        6             3
# 2       2              Sané       Bayern  Midfielder        6             3
# 3       4            Antony         Ajax     Forward        5             3
# 4       5  Alexander-Arnold    Liverpool    Defender        4            36
#
#    offsides  dribbles  match_played
# 0         2         7             7
# 1         4        83            13
# 2         3        32            10
# 3         4        28             7
# 4         0         9             9

# %%
attempt.head()
# Out:
#    serial  player_name         club    position  total_attempts  on_target  \
# 0       1      Benzema  Real Madrid     Forward              45         23
# 1       2        Salah    Liverpool     Forward              42         22
# 2       3       Mahrez    Man. City  Midfielder              37         18
# 3       4         Sané       Bayern  Midfielder              33         13
# 4       5  Lewandowski       Bayern     Forward              31         19
#
#    off_target  blocked  match_played
# 0          13        9            12
# 1          11        9            13
# 2           8       11            12
# 3          12        8            10
# 4           8        4            10

# %%
defend.head()
# Out:
#    serial   player_name         club    position  balls_recoverd  tackles  \
# 0       1      Casemiro  Real Madrid  Midfielder              76       31
# 1       1  Éder Militão  Real Madrid    Defender              76       19
# 2       1      Reinildo     Atlético    Defender              76       13
# 3       4       Fabinho    Liverpool  Midfielder              74       23
# 4       5        Albiol   Villarreal    Defender              73        9
#
#    t_won  t_lost  clearance_attempted  match_played
# 0     13      18                   19            11
# 1      6      13                   32            12
# 2      6       7                   20            10
# 3      9      14                    8            13
# 4      6       3                   62            12

# %%
disc.head()
# Out:
#    serial    player_name         club    position  fouls_committed  \
# 0       1  João Palhinha  Sporting CP  Midfielder               23
# 1       2         Capoue   Villarreal  Midfielder               19
# 2       2          Rodri    Man. City  Midfielder               19
# 3       2        Seiwald     Salzburg  Midfielder               19
# 4       5        Balanta  Club Brugge  Midfielder               18
#
#    fouls_suffered  red  yellow  minutes_played  match_played
# 0              17    2       0             534             6
# 1              17    3       1            1046            12
# 2               4    2       0             842            10
# 3               3    2       0             649             8
# 4               3    4       0             407             5

# %%
distri.head()
# Out:
#    serial  player_name       club    position  pass_accuracy  pass_attempted  \
# 0       1      Erokhin      Zenit  Midfielder           98.0              27
# 1       2  Eric García  Barcelona    Defender           97.5             203
# 2       3      Ulreich     Bayern  Goalkeeper           97.0              32
# 3       4       Rugani   Juventus    Defender           96.8             130
# 4       5    J. Timber       Ajax  Midfielder           95.8             497
#
#    pass_completed  cross_accuracy  cross_attempted  cross_complted  \
# 0              26               0                2               0
# 1             197               0                0               0
# 2              31               0                0               0
# 3             122               0                0               0
# 4             474               0                1               0
#
#    freekicks_taken  match_played
# 0                0             6
# ...

# %%
goalkeep.head()
# Out:
#    serial   player_name         club    position  saved  conceded  \
# 0       1      Courtois  Real Madrid  Goalkeeper     61        14
# 1       2         Rulli   Villarreal  Goalkeeper     41        16
# 2       3   Vlachodimos      Benfica  Goalkeeper     38        17
# 3       4  Athanasiadis      Sheriff  Goalkeeper     29         8
# 4       5      Mignolet  Club Brugge  Goalkeeper     28        20
#
#    saved_penalties  cleansheets  punches made  match_played
# 0                1            5             4            13
# 1                0            3            12            12
# 2                1            5             5            10
# 3                0            1             2             5
# 4                0            0             1             6

# %%
goal.head()
# Out:
#    serial  player_name         club    position  goals  right_foot  left_foot  \
# 0       1      Benzema  Real Madrid     Forward     15          11          1
# 1       2  Lewandowski       Bayern     Forward     13           8          3
# 2       3       Haller         Ajax     Forward     11           3          4
# 3       4        Salah    Liverpool     Forward      8           0          8
# 4       5       Nkunku      Leipzig  Midfielder      7           3          1
#
#    headers  others  inside_area  outside_areas  penalties  match_played
# 0        3       0           13              2          3            12
# 1        1       1           13              0          3            10
# 2        3       1           11              0          1             8
# 3        0       0            7              1          1            13
# 4        3       0            7              0          0             6

# %%
stats.head()
# Out:
#        player_name         club    position  minutes_played  match_played  \
# 0         Courtois  Real Madrid  Goalkeeper            1230            13
# 1  Vinícius Júnior  Real Madrid     Forward            1199            13
# 2          Benzema  Real Madrid     Forward            1106            12
# 3           Modrić  Real Madrid  Midfielder            1077            13
# 4     Éder Militão  Real Madrid    Defender            1076            12
#
#    goals  assists distance_covered
# 0      0        0             64.2
# 1      4        6            133.0
# 2     15        1            121.5
# 3      0        4            124.5
# 4      0        0            110.4

# %%
pd.concat([attack,attempt,distri,disc,goalkeep,goal,stats]).drop_duplicates(subset = ['player_name'],keep = 'first').player_name.nunique()
# Out:
# 732

# %%
goal.player_name
# Out:
# 0             Benzema
# 1         Lewandowski
# 2              Haller
# 3               Salah
# 4              Nkunku
#             ...
# 178           Yansané
# 179       Yakhshiboev
# 180    Messias Junior
# 181            Morato
# 182       Pedro Porro
# Name: player_name, Length: 183, dtype: object

# %%
mg1 = pd.merge(stats,goal,how = 'left')

# %%
list(stats.player_name) == list(goal.player_name)
# Out:
# False

# %%
pd.merge(mg1,goalkeep,how = 'right')
# Out:
#          player_name              club    position  minutes_played  \
# 0           Courtois       Real Madrid  Goalkeeper             NaN
# 1              Rulli        Villarreal  Goalkeeper             NaN
# 2        Vlachodimos           Benfica  Goalkeeper             NaN
# 3       Athanasiadis           Sheriff  Goalkeeper             NaN
# 4           Mignolet       Club Brugge  Goalkeeper             NaN
# 5              Oblak          Atlético  Goalkeeper             NaN
# 6              Musso          Atalanta  Goalkeeper             NaN
# 7   Ersin Destanoğlu          Beşiktaş  Goalkeeper             NaN
# 8             De Gea       Man. United  Goalkeeper             NaN
# 9             Dahlin             Malmö  Goalkeeper             NaN
# 10       Diogo Costa             Porto  Goalkeeper             NaN
# 11            Trubin  Shakhtar Donetsk  Goalkeeper             NaN
# 12          Casteels         Wolfsburg  Goalkeeper             NaN
# ...

# %%
mg1
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 742         Gil Dias      Benfica  Midfielder               1             1
# 743  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 744         Cojocari      Sheriff    Defender               1             1
# 745         Maouassa  Club Brugge    Defender               1             1
# 746          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
stats.head()
# Out:
#        player_name         club    position  minutes_played  match_played  \
# 0         Courtois  Real Madrid  Goalkeeper            1230            13
# 1  Vinícius Júnior  Real Madrid     Forward            1199            13
# 2          Benzema  Real Madrid     Forward            1106            12
# 3           Modrić  Real Madrid  Midfielder            1077            13
# 4     Éder Militão  Real Madrid    Defender            1076            12
#
#    goals  assists distance_covered
# 0      0        0             64.2
# 1      4        6            133.0
# 2     15        1            121.5
# 3      0        4            124.5
# 4      0        0            110.4

# %%
mg2 = pd.merge(stats,goalkeep,how = 'left')

# %%
pd.merge(stats,goal,how ='inner')
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0    Vinícius Júnior  Real Madrid     Forward            1199            13
# 1            Benzema  Real Madrid     Forward            1106            12
# 2              Alaba  Real Madrid    Defender            1040            12
# 3              Kroos  Real Madrid  Midfielder             902            12
# 4            Asensio  Real Madrid     Forward             207             8
# ..               ...          ...         ...             ...           ...
# 174          Alcácer   Villarreal     Forward              73             3
# 175    Choupo-Moting       Bayern  Midfielder              49             4
# 176           Palmer    Man. City  Midfielder              40             3
# 177        Kjærgaard     Salzburg  Midfielder              38             4
# 178           Ozdoev        Zenit  Midfielder              11             1
#
# ...

# %%
pd.merge(stats,goalkeep,how = 'inner')
# Out:
#          player_name              club    position  minutes_played  \
# 0           Courtois       Real Madrid  Goalkeeper            1230
# 1     Alisson Becker         Liverpool  Goalkeeper            1170
# 2              Rulli        Villarreal  Goalkeeper            1080
# 3            Ederson         Man. City  Goalkeeper            1003
# 4        Vlachodimos           Benfica  Goalkeeper             900
# 5              Oblak          Atlético  Goalkeeper             900
# 6              Mendy           Chelsea  Goalkeeper             840
# 7              Neuer            Bayern  Goalkeeper             810
# 8               Köhn          Salzburg  Goalkeeper             720
# 9         Handanovič             Inter  Goalkeeper             720
# 10              Adán       Sporting CP  Goalkeeper             630
# 11          Szczęsny          Juventus  Goalkeeper             630
# 12            De Gea       Man. United  Goalkeeper             630
# ...

# %%
pd.merge(stats,attempt,how = 'inner')
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0    Vinícius Júnior  Real Madrid     Forward            1199            13
# 1            Benzema  Real Madrid     Forward            1106            12
# 2             Modrić  Real Madrid  Midfielder            1077            13
# 3       Éder Militão  Real Madrid    Defender            1076            12
# 4              Alaba  Real Madrid    Defender            1040            12
# ..               ...          ...         ...             ...           ...
# 538        Izquierdo  Club Brugge     Forward               8             1
# 539      Dina Ebimbe        Paris  Midfielder               7             1
# 540            Šimić     Salzburg     Forward               4             1
# 541            Maier   Young Boys  Midfielder               3             1
# 542        Kuznetsov        Zenit     Forward               3             1
#
# ...

# %%
pd.merge(stats,distri,how='inner')
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 602            Günok     Beşiktaş  Goalkeeper              90             1
# 603        Celeadnic      Sheriff  Goalkeeper              90             1
# 604            Boyko  Dynamo Kyiv  Goalkeeper              90             1
# 605            Perin     Juventus  Goalkeeper              90             1
# 606          Steffen    Man. City  Goalkeeper              90             1
#
# ...

# %%
pd.merge(stats,disc,how='inner')
# Out:
#          player_name              club    position  minutes_played  \
# 0    Vinícius Júnior       Real Madrid     Forward            1199
# 1            Benzema       Real Madrid     Forward            1106
# 2             Modrić       Real Madrid  Midfielder            1077
# 3       Éder Militão       Real Madrid    Defender            1076
# 4              Alaba       Real Madrid    Defender            1040
# ..               ...               ...         ...             ...
# 577           Iborra        Villarreal  Midfielder              10
# 578         Zhegrova              LOSC  Midfielder               9
# 579        Chiellini          Juventus    Defender               7
# 580            Delap         Man. City     Forward               6
# 581         Dentinho  Shakhtar Donetsk  Midfielder               4
#
#      match_played  goals  assists distance_covered  serial  fouls_committed  \
# 0              13      4        6            133.0      26               13
# ...

# %%
pd.merge(stats,defend,how='inner')
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0    Vinícius Júnior  Real Madrid     Forward            1199            13
# 1            Benzema  Real Madrid     Forward            1106            12
# 2             Modrić  Real Madrid  Midfielder            1077            13
# 3       Éder Militão  Real Madrid    Defender            1076            12
# 4              Alaba  Real Madrid    Defender            1040            12
# ..               ...          ...         ...             ...           ...
# 620           Guindo     Salzburg    Defender               4             1
# 621            Maier   Young Boys  Midfielder               3             1
# 622        Kuznetsov        Zenit     Forward               3             1
# 623          Miretti     Juventus  Midfielder               1             1
# 624          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
attack.player_name.nunique()
# Out:
# 176

# %%
defend.player_name.nunique()
# Out:
# 617

# %%
attempt.player_name.nunique()
# Out:
# 540

# %%
goal.player_name.nunique()
# Out:
# 183

# %%
stats.player_name.nunique()
# Out:
# 731

# %%
goalkeep.player_name.nunique()
# Out:
# 53

# %%
disc.player_name.nunique()
# Out:
# 574

# %%
distri.player_name.nunique()
# Out:
# 595

# %%
m = pd.merge(stats,goalkeep,how = 'outer').drop_duplicates(subset = 'player_name',keep='first').reset_index()

# %%
m
# Out:
#      index      player_name         club    position  minutes_played  \
# 0        0         Courtois  Real Madrid  Goalkeeper            1230
# 1        1  Vinícius Júnior  Real Madrid     Forward            1199
# 2        2          Benzema  Real Madrid     Forward            1106
# 3        3           Modrić  Real Madrid  Midfielder            1077
# 4        4     Éder Militão  Real Madrid    Defender            1076
# ..     ...              ...          ...         ...             ...
# 726    742         Gil Dias      Benfica  Midfielder               1
# 727    743  Rodrigo Ribeiro  Sporting CP     Forward               1
# 728    744         Cojocari      Sheriff    Defender               1
# 729    745         Maouassa  Club Brugge    Defender               1
# 730    746          Zesiger   Young Boys    Defender               1
#
#      match_played  goals  assists distance_covered  serial  saved  conceded  \
# ...

# %%
pd.merge(m,attack,on= ['player_name','club','position'],how = 'left')
# Out:
#      index      player_name         club    position  minutes_played  \
# 0        0         Courtois  Real Madrid  Goalkeeper            1230
# 1        1  Vinícius Júnior  Real Madrid     Forward            1199
# 2        2          Benzema  Real Madrid     Forward            1106
# 3        3           Modrić  Real Madrid  Midfielder            1077
# 4        4     Éder Militão  Real Madrid    Defender            1076
# ..     ...              ...          ...         ...             ...
# 726    742         Gil Dias      Benfica  Midfielder               1
# 727    743  Rodrigo Ribeiro  Sporting CP     Forward               1
# 728    744         Cojocari      Sheriff    Defender               1
# 729    745         Maouassa  Club Brugge    Defender               1
# 730    746          Zesiger   Young Boys    Defender               1
#
#      match_played_x  goals  assists_x distance_covered  serial_x  saved  \
# ...

# %%
goal.head()
# Out:
#    serial  player_name         club    position  goals  right_foot  left_foot  \
# 0       1      Benzema  Real Madrid     Forward     15          11          1
# 1       2  Lewandowski       Bayern     Forward     13           8          3
# 2       3       Haller         Ajax     Forward     11           3          4
# 3       4        Salah    Liverpool     Forward      8           0          8
# 4       5       Nkunku      Leipzig  Midfielder      7           3          1
#
#    headers  others  inside_area  outside_areas  penalties  match_played
# 0        3       0           13              2          3            12
# 1        1       1           13              0          3            10
# 2        3       1           11              0          1             8
# 3        0       0            7              1          1            13
# 4        3       0            7              0          0             6

# %%
stats[stats.duplicated('player_name')]
# Out:
#     player_name              club    position  minutes_played  match_played  \
# 71        Mendy           Chelsea  Goalkeeper             840             9
# 130    Martínez             Inter     Forward             587             8
# 333      Danilo             Paris  Midfielder             362             7
# 348  João Mário             Porto     Forward             351             4
# 349    Fernando  Shakhtar Donetsk  Midfielder             350             5
# 354      Camara        Young Boys    Defender             347             4
# 467     Herrera          Atlético  Midfielder             226             4
# 514       Onana              Ajax  Goalkeeper             180             2
# 543    Karavaev       Dynamo Kyiv    Defender             154             6
# 580      Correa             Inter     Forward             106             5
# 588        Sarr           Chelsea    Defender             100             2
# ...

# %%
pd.merge([attack,goal,defend,goalkeep,stats],on='player_name',how='right')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [128], in <cell line: 1>()
# ----> 1 pd.merge([attack,goal,defend,goalkeep,stats],on='player_name',how='right')
#
# TypeError: merge() missing 1 required positional argument: 'right'

# %%
attack.head()
# Out:
#    serial       player_name         club    position  assists  corner_taken  \
# 0       1   Bruno Fernandes  Man. United  Midfielder        7            10
# 1       2   Vinícius Júnior  Real Madrid     Forward        6             3
# 2       2              Sané       Bayern  Midfielder        6             3
# 3       4            Antony         Ajax     Forward        5             3
# 4       5  Alexander-Arnold    Liverpool    Defender        4            36
#
#    offsides  dribbles  match_played
# 0         2         7             7
# 1         4        83            13
# 2         3        32            10
# 3         4        28             7
# 4         0         9             9

# %%
stats.drop_duplicates(subset='player_name',keep ='first',inplace =True)

# %%
stats.reset_index(drop =True,inplace =True)

# %%
stats
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 726         Gil Dias      Benfica  Midfielder               1             1
# 727  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 728         Cojocari      Sheriff    Defender               1             1
# 729         Maouassa  Club Brugge    Defender               1             1
# 730          Zesiger   Young Boys    Defender               1             1
#
#      goals  assists distance_covered
# ...

# %%
attempt.drop_duplicates(subset='player_name',keep ='first',inplace =True)

# %%
attempt.reset_index(drop =True,inplace =True)

# %%
disc.drop_duplicates(subset='player_name',keep ='first',inplace =True)

# %%
disc.reset_index(drop =True,inplace =True)

# %%
distri.drop_duplicates(subset='player_name',keep ='first',inplace =True)

# %%
distri.reset_index(drop =True,inplace =True)

# %%
defend.drop_duplicates(subset='player_name',keep ='first',inplace =True)
defend.reset_index(drop =True,inplace =True)

# %%
goalkeep.drop_duplicates(subset='player_name',keep ='first',inplace =True)
goalkeep.reset_index(drop =True,inplace =True)

# %%
goal.drop_duplicates(subset='player_name',keep ='first',inplace =True)
goal.reset_index(drop =True,inplace =True)

# %%
stats.drop_duplicates(subset='player_name',keep ='first',inplace =True)
stats.reset_index(drop =True,inplace =True)

# %%
attack.head()
# Out:
#    serial       player_name         club    position  assists  corner_taken  \
# 0       1   Bruno Fernandes  Man. United  Midfielder        7            10
# 1       2   Vinícius Júnior  Real Madrid     Forward        6             3
# 2       2              Sané       Bayern  Midfielder        6             3
# 3       4            Antony         Ajax     Forward        5             3
# 4       5  Alexander-Arnold    Liverpool    Defender        4            36
#
#    offsides  dribbles  match_played
# 0         2         7             7
# 1         4        83            13
# 2         3        32            10
# 3         4        28             7
# 4         0         9             9

# %%
stats.head()
# Out:
#        player_name         club    position  minutes_played  match_played  \
# 0         Courtois  Real Madrid  Goalkeeper            1230            13
# 1  Vinícius Júnior  Real Madrid     Forward            1199            13
# 2          Benzema  Real Madrid     Forward            1106            12
# 3           Modrić  Real Madrid  Midfielder            1077            13
# 4     Éder Militão  Real Madrid    Defender            1076            12
#
#    goals  assists distance_covered
# 0      0        0             64.2
# 1      4        6            133.0
# 2     15        1            121.5
# 3      0        4            124.5
# 4      0        0            110.4

# %%
m1 = pd.merge(stats,attack,on=['player_name','club','position','match_played','assists'],how = 'left')

# %%
m1
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 726         Gil Dias      Benfica  Midfielder               1             1
# 727  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 728         Cojocari      Sheriff    Defender               1             1
# 729         Maouassa  Club Brugge    Defender               1             1
# 730          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
goalkeep.head()
# Out:
#    serial   player_name         club    position  saved  conceded  \
# 0       1      Courtois  Real Madrid  Goalkeeper     61        14
# 1       2         Rulli   Villarreal  Goalkeeper     41        16
# 2       3   Vlachodimos      Benfica  Goalkeeper     38        17
# 3       4  Athanasiadis      Sheriff  Goalkeeper     29         8
# 4       5      Mignolet  Club Brugge  Goalkeeper     28        20
#
#    saved_penalties  cleansheets  punches made  match_played
# 0                1            5             4            13
# 1                0            3            12            12
# 2                1            5             5            10
# 3                0            1             2             5
# 4                0            0             1             6

# %%
m2 = pd.merge(m1,goalkeep,on = ['player_name','club','position','match_played'],how = 'left').drop(['serial_x','serial_y'],axis = 1)

# %%
m2
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 726         Gil Dias      Benfica  Midfielder               1             1
# 727  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 728         Cojocari      Sheriff    Defender               1             1
# 729         Maouassa  Club Brugge    Defender               1             1
# 730          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
goal.head()
# Out:
#    serial  player_name         club    position  goals  right_foot  left_foot  \
# 0       1      Benzema  Real Madrid     Forward     15          11          1
# 1       2  Lewandowski       Bayern     Forward     13           8          3
# 2       3       Haller         Ajax     Forward     11           3          4
# 3       4        Salah    Liverpool     Forward      8           0          8
# 4       5       Nkunku      Leipzig  Midfielder      7           3          1
#
#    headers  others  inside_area  outside_areas  penalties  match_played
# 0        3       0           13              2          3            12
# 1        1       1           13              0          3            10
# 2        3       1           11              0          1             8
# 3        0       0            7              1          1            13
# 4        3       0            7              0          0             6

# %%
m3 =  pd.merge(m2,goal,on = ['player_name','club','position','match_played','goals'],how = 'left').drop('serial',axis =1)

# %%
m3
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 726         Gil Dias      Benfica  Midfielder               1             1
# 727  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 728         Cojocari      Sheriff    Defender               1             1
# 729         Maouassa  Club Brugge    Defender               1             1
# 730          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
attempt.drop('serial',axis=1,inplace=True)

# %%
m4 = pd.merge(m3,attempt,on = ['player_name','club','position','match_played'],how = 'left')

# %%
m4
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 726         Gil Dias      Benfica  Midfielder               1             1
# 727  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 728         Cojocari      Sheriff    Defender               1             1
# 729         Maouassa  Club Brugge    Defender               1             1
# 730          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
defend.drop('serial',axis= 1,inplace=True)

# %%
 m5 = pd.merge(m4,defend,on = ['player_name','club','position','match_played'],how = 'left')

# %%
m5
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 726         Gil Dias      Benfica  Midfielder               1             1
# 727  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 728         Cojocari      Sheriff    Defender               1             1
# 729         Maouassa  Club Brugge    Defender               1             1
# 730          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
disc.drop('serial',axis= 1,inplace=True)

# %%
disc
# Out:
#        player_name         club    position  fouls_committed  fouls_suffered  \
# 0    João Palhinha  Sporting CP  Midfielder               23              17
# 1           Capoue   Villarreal  Midfielder               19              17
# 2            Rodri    Man. City  Midfielder               19               4
# 3          Seiwald     Salzburg  Midfielder               19               3
# 4          Balanta  Club Brugge  Midfielder               18               3
# ..             ...          ...         ...              ...             ...
# 569   Eric Ramirez  Dynamo Kyiv     Forward                1               0
# 570       Bradarić         LOSC    Defender                1               0
# 571         Iborra   Villarreal  Midfielder                1               0
# 572       Zhegrova         LOSC  Midfielder                1               0
# 573      Chiellini     Juventus    Defender                1               0
#
# ...

# %%
 m6 = pd.merge(m5,disc,on = ['player_name','club','position','match_played','minutes_played'],how = 'left')

# %%
distri.drop('serial',axis= 1,inplace=True)

# %%
m7 = pd.merge(m6,distri,on = ['player_name','club','position','match_played'],how = 'left')

# %%
m7.columns
# Out:
# Index(['player_name', 'club', 'position', 'minutes_played', 'match_played',
#        'goals', 'assists', 'distance_covered', 'corner_taken', 'offsides',
#        'dribbles', 'saved', 'conceded', 'saved_penalties', 'cleansheets',
#        'punches made', 'right_foot', 'left_foot', 'headers', 'others',
#        'inside_area', 'outside_areas', 'penalties', 'total_attempts',
#        'on_target', 'off_target', 'blocked', 'balls_recoverd', 'tackles',
#        't_won', 't_lost', 'clearance_attempted', 'fouls_committed',
#        'fouls_suffered', 'red', 'yellow', 'pass_accuracy', 'pass_attempted',
#        'pass_completed', 'cross_accuracy', 'cross_attempted', 'cross_complted',
#        'freekicks_taken'],
#       dtype='object')

# %%
m8 = m7.replace('[-]','0',regex=True)

# %%
m8.iloc[m8.distance_covered.astype(float).sort_values(ascending=False).index]
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 55            Parejo   Villarreal  Midfielder            1055            12
# 56            Capoue   Villarreal  Midfielder            1046            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 53        Pau Torres   Villarreal    Defender            1080            12
# ..               ...          ...         ...             ...           ...
# 52           Bradley    Liverpool  Midfielder               1             1
# 51           Woltman    Liverpool  Midfielder               1             1
# 729         Maouassa  Club Brugge    Defender               1             1
# 709        Sulejmani   Young Boys  Midfielder               7             1
# 730          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
m8.sort_values(by=['goals','match_played','assists'],ascending=[False,True,False]).head(10).dropna(axis=1)
# Out:
#      player_name         club    position  minutes_played  match_played  \
# 2        Benzema  Real Madrid     Forward            1106            12
# 66   Lewandowski       Bayern     Forward             876            10
# 101       Haller         Ajax     Forward             668             8
# 26         Salah    Liverpool     Forward            1008            13
# 182       Nkunku      Leipzig  Midfielder             531             6
# 59        Mahrez    Man. City  Midfielder             986            12
# 125      Ronaldo  Man. United     Forward             611             7
# 98        Mbappé        Paris     Forward             673             8
# 75          Sané       Bayern  Midfielder             798            10
# 123        Núñez      Benfica     Forward             613            10
#
#      goals  assists distance_covered  right_foot  left_foot  headers  others  \
# 2       15        1            121.5        11.0        1.0      3.0     0.0
# ...

# %%
m8.sort_values(by = ['saved','conceded','saved_penalties','cleansheets','punches made'],ascending = [False,True,True,False,False]).head(15).dropna(axis =1)
# Out:
#           player_name              club    position  minutes_played  \
# 0            Courtois       Real Madrid  Goalkeeper            1230
# 54              Rulli        Villarreal  Goalkeeper            1080
# 62        Vlachodimos           Benfica  Goalkeeper             900
# 259      Athanasiadis           Sheriff  Goalkeeper             450
# 166          Mignolet       Club Brugge  Goalkeeper             540
# 63              Oblak          Atlético  Goalkeeper             900
# 167             Musso          Atalanta  Goalkeeper             540
# 255  Ersin Destanoğlu          Beşiktaş  Goalkeeper             450
# 381            Dahlin             Malmö  Goalkeeper             315
# 120            De Gea       Man. United  Goalkeeper             630
# 256        Donnarumma             Paris  Goalkeeper             450
# 254          Casteels         Wolfsburg  Goalkeeper             450
# 423            Trubin  Shakhtar Donetsk  Goalkeeper             270
# ...

# %%
m8
# Out:
#          player_name         club    position  minutes_played  match_played  \
# 0           Courtois  Real Madrid  Goalkeeper            1230            13
# 1    Vinícius Júnior  Real Madrid     Forward            1199            13
# 2            Benzema  Real Madrid     Forward            1106            12
# 3             Modrić  Real Madrid  Midfielder            1077            13
# 4       Éder Militão  Real Madrid    Defender            1076            12
# ..               ...          ...         ...             ...           ...
# 726         Gil Dias      Benfica  Midfielder               1             1
# 727  Rodrigo Ribeiro  Sporting CP     Forward               1             1
# 728         Cojocari      Sheriff    Defender               1             1
# 729         Maouassa  Club Brugge    Defender               1             1
# 730          Zesiger   Young Boys    Defender               1             1
#
# ...

# %%
m8.sort_values(by = ['tackles','t_won','t_lost','fouls_committed','red','yellow'],ascending = [False,False,True,True,True,True]).head(15)
# Out:
#            player_name         club    position  minutes_played  match_played  \
# 278           Verratti        Paris  Midfielder             431             5
# 7             Casemiro  Real Madrid  Midfielder             914            11
# 178      João Palhinha  Sporting CP  Midfielder             534             6
# 74            Otamendi      Benfica    Defender             810             9
# 213               Addo      Sheriff  Midfielder             491             6
# 116              André         LOSC  Midfielder             630             7
# 73               Weigl      Benfica  Midfielder             810             9
# 27             Fabinho    Liverpool  Midfielder             849            13
# 224         Renan Lodi     Atlético    Defender             478            10
# 266              Souza     Beşiktaş  Midfielder             442             5
# 64               Foyth   Villarreal    Defender             891            10
# ...

# %%
m8.sort_values(by='yellow',ascending = False).head(10).dropna(axis=1)
# Out:
#      player_name         club    position  minutes_played  match_played  \
# 229       Felipe     Atlético    Defender             472             7
# 275     Angeliño      Leipzig    Defender             432             5
# 56        Capoue   Villarreal  Midfielder            1046            12
# 291  Ahmedhodžić        Malmö    Defender             413             5
# 624     Emre Can     Dortmund    Defender              74             2
# 286  Wan0Bissaka  Man. United    Defender             419             6
# 374       Kessié        Milan  Midfielder             321             5
# 613    En0Nesyri      Sevilla     Forward              83             2
# 383     Welinton     Beşiktaş    Defender             313             4
# 367       Jordán      Sevilla  Midfielder             327             6
#
#      goals  assists distance_covered  fouls_committed  fouls_suffered  red  \
# 229      0        0             51.4              7.0             2.0  3.0
# ...

# %%
m8.loc[:,['player_name','club','goals']].sort_values(by= 'goals',ascending =False).head(15).style.background_gradient("Greens")
# Out:
# <style type="text/css">
# #T_eedf4_row0_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_eedf4_row1_col2 {
#   background-color: #157f3b;
#   color: #f1f1f1;
# }
# #T_eedf4_row2_col2 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_eedf4_row3_col2 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_eedf4_row4_col2, #T_eedf4_row5_col2 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_eedf4_row6_col2, #T_eedf4_row7_col2, #T_eedf4_row8_col2, #T_eedf4_row9_col2, #T_eedf4_row10_col2 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_eedf4_row11_col2, #T_eedf4_row12_col2, #T_eedf4_row13_col2, #T_eedf4_row14_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_eedf4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_eedf4_level0_col0" class="col_heading level0 col0" >player_name</th>
# ...

# %%
m8.loc[:,['player_name','club','saved','conceded','cleansheets']].sort_values(by= ['saved','conceded','cleansheets'],ascending =[False,True,False]).head(10)
# Out:
#           player_name         club  saved  conceded  cleansheets
# 0            Courtois  Real Madrid   61.0      14.0          5.0
# 54              Rulli   Villarreal   41.0      16.0          3.0
# 62        Vlachodimos      Benfica   38.0      17.0          5.0
# 259      Athanasiadis      Sheriff   29.0       8.0          1.0
# 166          Mignolet  Club Brugge   28.0      20.0          0.0
# 63              Oblak     Atlético   26.0      10.0          3.0
# 167             Musso     Atalanta   21.0      13.0          1.0
# 255  Ersin Destanoğlu     Beşiktaş   20.0      17.0          0.0
# 381            Dahlin        Malmö   19.0       8.0          0.0
# 120            De Gea  Man. United   19.0       9.0          1.0

# %%
m8.loc[:,['player_name','club','red']].sort_values(by= 'red',ascending =False).head(15).style.background_gradient("Wistia_r")
# Out:
# <style type="text/css">
# #T_1a9e7_row0_col2, #T_1a9e7_row1_col2, #T_1a9e7_row2_col2, #T_1a9e7_row3_col2, #T_1a9e7_row4_col2, #T_1a9e7_row5_col2 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# #T_1a9e7_row6_col2, #T_1a9e7_row7_col2, #T_1a9e7_row8_col2, #T_1a9e7_row9_col2, #T_1a9e7_row10_col2, #T_1a9e7_row11_col2, #T_1a9e7_row12_col2, #T_1a9e7_row13_col2, #T_1a9e7_row14_col2 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1a9e7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a9e7_level0_col0" class="col_heading level0 col0" >player_name</th>
#       <th id="T_1a9e7_level0_col1" class="col_heading level0 col1" >club</th>
#       <th id="T_1a9e7_level0_col2" class="col_heading level0 col2" >red</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a9e7_level0_row0" class="row_heading level0 row0" >145</th>
#       <td id="T_1a9e7_row0_col0" class="data row0 col0" >Álvarez</td>
# ...

# %%
m8.loc[:,['player_name','club','yellow']].sort_values(by= 'yellow',ascending =False).head(15).style.background_gradient("Wistia_r")
# Out:
# <style type="text/css">
# #T_bb56d_row0_col2 {
#   background-color: #e4ff7a;
#   color: #000000;
# }
# #T_bb56d_row1_col2, #T_bb56d_row2_col2, #T_bb56d_row3_col2, #T_bb56d_row4_col2, #T_bb56d_row5_col2, #T_bb56d_row6_col2, #T_bb56d_row7_col2, #T_bb56d_row8_col2, #T_bb56d_row9_col2, #T_bb56d_row10_col2, #T_bb56d_row11_col2, #T_bb56d_row12_col2, #T_bb56d_row13_col2, #T_bb56d_row14_col2 {
#   background-color: #fc7f00;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bb56d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bb56d_level0_col0" class="col_heading level0 col0" >player_name</th>
#       <th id="T_bb56d_level0_col1" class="col_heading level0 col1" >club</th>
#       <th id="T_bb56d_level0_col2" class="col_heading level0 col2" >yellow</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bb56d_level0_row0" class="row_heading level0 row0" >229</th>
#       <td id="T_bb56d_row0_col0" class="data row0 col0" >Felipe</td>
# ...

# %%
m8.loc[:,['player_name','pass_accuracy','pass_attempted']].sort_values(by= ['pass_attempted','pass_accuracy'],ascending =[False,False]).head(15).style.background_gradient("Greens")
# Out:
# <style type="text/css">
# #T_a300d_row0_col1 {
#   background-color: #127c39;
#   color: #f1f1f1;
# }
# #T_a300d_row0_col2, #T_a300d_row4_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_a300d_row1_col1 {
#   background-color: #004e1f;
#   color: #f1f1f1;
# }
# #T_a300d_row1_col2 {
#   background-color: #005221;
#   color: #f1f1f1;
# }
# #T_a300d_row2_col1 {
#   background-color: #37a055;
#   color: #f1f1f1;
# }
# #T_a300d_row2_col2 {
#   background-color: #005e26;
#   color: #f1f1f1;
# }
# #T_a300d_row3_col1 {
#   background-color: #2f974e;
#   color: #f1f1f1;
# }
# #T_a300d_row3_col2 {
#   background-color: #3aa357;
#   color: #f1f1f1;
# }
# #T_a300d_row4_col2 {
#   background-color: #90d18d;
#   color: #000000;
# }
# #T_a300d_row5_col1 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_a300d_row5_col2 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_a300d_row6_col1, #T_a300d_row14_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# ...

# %%
m8.columns
# Out:
# Index(['player_name', 'club', 'position', 'minutes_played', 'match_played',
#        'goals', 'assists', 'distance_covered', 'corner_taken', 'offsides',
#        'dribbles', 'saved', 'conceded', 'saved_penalties', 'cleansheets',
#        'punches made', 'right_foot', 'left_foot', 'headers', 'others',
#        'inside_area', 'outside_areas', 'penalties', 'total_attempts',
#        'on_target', 'off_target', 'blocked', 'balls_recoverd', 'tackles',
#        't_won', 't_lost', 'clearance_attempted', 'fouls_committed',
#        'fouls_suffered', 'red', 'yellow', 'pass_accuracy', 'pass_attempted',
#        'pass_completed', 'cross_accuracy', 'cross_attempted', 'cross_complted',
#        'freekicks_taken'],
#       dtype='object')

# %%
m8.insert(24,'on_target_rate',m8.on_target/m8.total_attempts)

# %%
m8.loc[:,['player_name','on_target_rate','total_attempts']].sort_values(by= ['total_attempts'],ascending =[False]).head(15).style.background_gradient("Greens")
# Out:
# <style type="text/css">
# #T_00f46_row0_col1 {
#   background-color: #39a257;
#   color: #f1f1f1;
# }
# #T_00f46_row0_col2, #T_00f46_row12_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_00f46_row1_col1 {
#   background-color: #2f984f;
#   color: #f1f1f1;
# }
# #T_00f46_row1_col2 {
#   background-color: #026f2e;
#   color: #f1f1f1;
# }
# #T_00f46_row2_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_00f46_row2_col2 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_00f46_row3_col1 {
#   background-color: #b6e2af;
#   color: #000000;
# }
# #T_00f46_row3_col2 {
#   background-color: #84cc83;
#   color: #000000;
# }
# #T_00f46_row4_col1 {
#   background-color: #005020;
#   color: #f1f1f1;
# }
# #T_00f46_row4_col2 {
#   background-color: #a4da9e;
#   color: #000000;
# }
# #T_00f46_row5_col1 {
#   background-color: #f5fbf3;
#   color: #000000;
# }
# #T_00f46_row5_col2, #T_00f46_row6_col2 {
#   background-color: #d8f0d2;
#   color: #000000;
# ...

# %%
m8.loc[:,['player_name','cross_attempted','cross_accuracy']].sort_values(by= ['cross_attempted'],ascending =[False]).head(15).style.background_gradient("Greens")
# Out:
# <style type="text/css">
# #T_c6d2a_row0_col1, #T_c6d2a_row11_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c6d2a_row0_col2, #T_c6d2a_row12_col2 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_c6d2a_row1_col1 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_c6d2a_row1_col2, #T_c6d2a_row4_col2 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_c6d2a_row2_col1 {
#   background-color: #b2e0ac;
#   color: #000000;
# }
# #T_c6d2a_row2_col2 {
#   background-color: #e7f6e3;
#   color: #000000;
# }
# #T_c6d2a_row3_col1 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_c6d2a_row3_col2 {
#   background-color: #92d28f;
#   color: #000000;
# }
# #T_c6d2a_row4_col1 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_c6d2a_row5_col1 {
#   background-color: #d0edca;
#   color: #000000;
# }
# #T_c6d2a_row5_col2 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_c6d2a_row6_col1 {
#   background-color: #dbf1d5;
# ...

# %%
m8.loc[:,['player_name','saved','cleansheets']].sort_values(by = ['saved','cleansheets'],ascending =[False,False]).head(15).style.background_gradient('Greens')
# Out:
# <style type="text/css">
# #T_2da75_row0_col1, #T_2da75_row0_col2, #T_2da75_row2_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2da75_row1_col1 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_2da75_row1_col2, #T_2da75_row5_col2 {
#   background-color: #4bb062;
#   color: #f1f1f1;
# }
# #T_2da75_row2_col1 {
#   background-color: #7cc87c;
#   color: #000000;
# }
# #T_2da75_row3_col1 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_2da75_row3_col2, #T_2da75_row6_col2, #T_2da75_row8_col2, #T_2da75_row12_col2 {
#   background-color: #d3eecd;
#   color: #000000;
# }
# #T_2da75_row4_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_2da75_row4_col2, #T_2da75_row7_col2, #T_2da75_row9_col2, #T_2da75_row13_col2, #T_2da75_row14_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2da75_row5_col1 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_2da75_row6_col1 {
#   background-color: #eaf7e6;
# ...

# %%
m8.loc[:,['player_name','club','cross_attempted','cross_complted']].sort_values(by = ['cross_complted','cross_attempted'],ascending =[False,False]).head(15).style.background_gradient('Greens')
# Out:
# <style type="text/css">
# #T_c15cd_row0_col2, #T_c15cd_row0_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_c15cd_row1_col2 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_c15cd_row1_col3 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_c15cd_row2_col2 {
#   background-color: #c0e6b9;
#   color: #000000;
# }
# #T_c15cd_row2_col3 {
#   background-color: #45ad5f;
#   color: #f1f1f1;
# }
# #T_c15cd_row3_col2 {
#   background-color: #a8dca2;
#   color: #000000;
# }
# #T_c15cd_row3_col3 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_c15cd_row4_col2 {
#   background-color: #3ca559;
#   color: #f1f1f1;
# }
# #T_c15cd_row4_col3, #T_c15cd_row5_col3 {
#   background-color: #9ed798;
#   color: #000000;
# }
# #T_c15cd_row5_col2, #T_c15cd_row7_col2, #T_c15cd_row9_col2, #T_c15cd_row11_col3, #T_c15cd_row12_col3, #T_c15cd_row13_col3 {
#   background-color: #ecf8e8;
#   color: #000000;
# }
# #T_c15cd_row6_col2 {
# ...
