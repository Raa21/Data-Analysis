# %%
import pandas as pd
import numpy as np
pd.set_option("display.max_columns",None)

# %%
df = pd.read_csv("C:/Users/rajen/Data Analysis/nutrition.csv",index_col=0)

# %%
df
# Out:
#                                                    name serving_size  \
# 0                                            Cornstarch        100 g
# 1                                          Nuts, pecans        100 g
# 2                                         Eggplant, raw        100 g
# 3                                        Teff, uncooked        100 g
# 4                                       Sherbet, orange        100 g
# ...                                                 ...          ...
# 8784  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8785  Lamb, cooked, separable lean only, composite o...        100 g
# 8786  Lamb, raw, separable lean and fat, composite o...        100 g
# 8787  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
# 8788  Beef, raw, all grades, trimmed to 0" fat, sepa...        100 g
#
#       calories total_fat saturated_fat cholesterol    sodium  choline  \
# ...

# %%
nutrition = df.set_index('name')

# %%
nutrition
# Out:
#                                                    serving_size  calories  \
# name
# Cornstarch                                                100 g       381
# Nuts, pecans                                              100 g       691
# Eggplant, raw                                             100 g        25
# Teff, uncooked                                            100 g       367
# Sherbet, orange                                           100 g       144
# ...                                                         ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       125
# Lamb, cooked, separable lean only, composite of...        100 g       206
# Lamb, raw, separable lean and fat, composite of...        100 g       277
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       121
# Beef, raw, all grades, trimmed to 0" fat, separ...        100 g       121
#
# ...

# %%
nutrition.head(10)
# Out:
#                    serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch                100 g       381      0.1g           NaN           0
# Nuts, pecans              100 g       691       72g          6.2g           0
# Eggplant, raw             100 g        25      0.2g           NaN           0
# Teff, uncooked            100 g       367      2.4g          0.4g           0
# Sherbet, orange           100 g       144        2g          1.2g         1mg
# Cauliflower, raw          100 g        25      0.3g          0.1g           0
# Taro leaves, raw          100 g        42      0.7g          0.2g           0
# Lamb, raw, ground         100 g       282       23g           10g        73mg
# Cheese, camembert         100 g       300       24g           15g        72mg
# Vegetarian fillets        100 g       290       18g          2.8g           0
#
#                        sodium  choline      folate folic_acid     niacin  ...  \
# ...

# %%
nutrition.loc['Nuts, pecans':'Taro leaves, raw','calories':'cholesterol']
# Out:
#                   calories total_fat saturated_fat cholesterol
# name
# Nuts, pecans           691       72g          6.2g           0
# Eggplant, raw           25      0.2g           NaN           0
# Teff, uncooked         367      2.4g          0.4g           0
# Sherbet, orange        144        2g          1.2g         1mg
# Cauliflower, raw        25      0.3g          0.1g           0
# Taro leaves, raw        42      0.7g          0.2g           0

# %%
nutrition.at['Cheese, camembert','fat']
# Out:
# '24.26 g'

# %%
nutrition.loc[
    ['Blackberries, raw','Raspberries, raw','Blueberries, raw'],
    'calories':'cholesterol'
]
# Out:
#                    calories total_fat saturated_fat cholesterol
# name
# Blackberries, raw        43      0.5g           NaN           0
# Raspberries, raw         52      0.7g           NaN           0
# Blueberries, raw         57      0.3g           NaN           0

# %%
nutrition.iloc[[5,50,14],2:5]
# Out:
#                       total_fat saturated_fat cholesterol
# name
# Cauliflower, raw           0.3g          0.1g           0
# KEEBLER, Waffle Cones      5.3g          0.9g           0
# Chicken, boiled, feet       15g          3.9g        84mg

# %%
nutrition.loc[
    ['Blackberries, raw','Blueberries, raw','Raspberries, raw'],
    ['calories','fat','cholesterol']
]
# Out:
#                    calories     fat cholesterol
# name
# Blackberries, raw        43  0.49 g           0
# Blueberries, raw         57  0.33 g           0
# Raspberries, raw         52  0.65 g           0

# %%
nutrition.info(verbose=False, memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8789 entries, Cornstarch to Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round
# Columns: 75 entries, serving_size to water
# dtypes: int64(2), object(73)
# memory usage: 39.4 MB

# %%
label_index = nutrition.index[2]

# %%
label_col = 'vitamin_k'

# %%
nutrition.at[label_index,label_col]
# Out:
# '3.5 mcg'

# %%
nutrition.columns.get_loc('vitamin_k')
# Out:
# 26

# %%
nutr_mini = nutrition.sample(10)
nutr_mini
# Out:
#                                                    serving_size  calories  \
# name
# Egg substitute, fat free, liquid or frozen                100 g        48
# Sauce, prepared from recipe, sofrito                      100 g       237
# Soup, powder, dry, cream of vegetable                     100 g       446
# MOTHER'S, Taffy Sandwich Cookies                          100 g       475
# Cocoa, plain, hi-fat or breakfast, dry powder             100 g       486
# Beans, without salt, boiled, cooked, mature see...        100 g       127
# MORNINGSTAR FARMS Roasted Garlic & Quinoa Burge...        100 g       192
# Cereals ready-to-eat, UNCLE SAM CEREAL                    100 g       346
# Cherries, raw, sweet                                      100 g        63
# Mushrooms, raw, shiitake                                  100 g        34
#
#                                                    total_fat saturated_fat  \
# name
# ...

# %%
nutr_mini.loc[
    :,['total_fat','cholesterol']
]
# Out:
#                                                    total_fat cholesterol
# name
# Egg substitute, fat free, liquid or frozen                0g           0
# Sauce, prepared from recipe, sofrito                     18g           0
# Soup, powder, dry, cream of vegetable                    24g         2mg
# MOTHER'S, Taffy Sandwich Cookies                         20g           0
# Cocoa, plain, hi-fat or breakfast, dry powder            24g           0
# Beans, without salt, boiled, cooked, mature see...      0.5g           0
# MORNINGSTAR FARMS Roasted Garlic & Quinoa Burge...       12g         1mg
# Cereals ready-to-eat, UNCLE SAM CEREAL                   12g           0
# Cherries, raw, sweet                                    0.2g           0
# Mushrooms, raw, shiitake                                0.5g           0

# %%
nutr_mini.columns.get_loc('vitamin_b12')
# Out:
# 20

# %%
nutr_mini.iloc[
    :3,20:
]
# Out:
#                                            vitamin_b12 vitamin_b6 vitamin_c  \
# name
# Egg substitute, fat free, liquid or frozen    0.34 mcg   0.133 mg    0.5 mg
# Sauce, prepared from recipe, sofrito                 0   0.364 mg   20.4 mg
# Soup, powder, dry, cream of vegetable         0.50 mcg   0.100 mg   16.6 mg
#
#                                            vitamin_d vitamin_e  \
# name
# Egg substitute, fat free, liquid or frozen  66.00 IU   1.59 mg
# Sauce, prepared from recipe, sofrito               0         0
# Soup, powder, dry, cream of vegetable        0.00 IU   2.41 mg
#
#                                            tocopherol_alpha vitamin_k  \
# name
# Egg substitute, fat free, liquid or frozen          1.59 mg   0.2 mcg
# Sauce, prepared from recipe, sofrito                      0         0
# Soup, powder, dry, cream of vegetable               2.41 mg  32.9 mcg
#
#                                               calcium    copper     irom  ...  \
# ...

# %%
l_index = 2

# %%
l_col = nutr_mini.columns.get_loc('calories')

# %%
nutr_mini.iat[l_index,l_col]
# Out:
# 446

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  ...  \
# name                                                                ...
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg  ...
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg  ...
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg  ...
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg  ...
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg  ...
#
# ...

# %%
nutr_cal = nutrition.iloc[
    0:10,0
]

# %%
nutr_cal.replace('\sg','',regex=True).astype(int)
# Out:
# name
# Cornstarch            100
# Nuts, pecans          100
# Eggplant, raw         100
# Teff, uncooked        100
# Sherbet, orange       100
# Cauliflower, raw      100
# Taro leaves, raw      100
# Lamb, raw, ground     100
# Cheese, camembert     100
# Vegetarian fillets    100
# Name: serving_size, dtype: int32

# %%
nutrition.head()
# Out:
#                 serving_size  calories total_fat saturated_fat cholesterol  \
# name
# Cornstarch             100 g       381      0.1g           NaN           0
# Nuts, pecans           100 g       691       72g          6.2g           0
# Eggplant, raw          100 g        25      0.2g           NaN           0
# Teff, uncooked         100 g       367      2.4g          0.4g           0
# Sherbet, orange        100 g       144        2g          1.2g         1mg
#
#                    sodium  choline     folate folic_acid    niacin  \
# name
# Cornstarch        9.00 mg   0.4 mg   0.00 mcg   0.00 mcg  0.000 mg
# Nuts, pecans      0.00 mg  40.5 mg  22.00 mcg   0.00 mcg  1.167 mg
# Eggplant, raw     2.00 mg   6.9 mg  22.00 mcg   0.00 mcg  0.649 mg
# Teff, uncooked   12.00 mg  13.1 mg          0          0  3.363 mg
# Sherbet, orange  46.00 mg   7.7 mg   4.00 mcg   0.00 mcg  0.063 mg
#
#                 pantothenic_acid riboflavin   thiamin vitamin_a vitamin_a_rae  \
# name
# ...

# %%
units = nutrition.astype(str).replace('[^a-zA-Z]','',regex=True)

# %%
units.mode()
# Out:
#   serving_size calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g                  g             g          mg     mg      mg
#
#   folate folic_acid niacin pantothenic_acid riboflavin thiamin vitamin_a  \
# 0    mcg        mcg     mg               mg         mg      mg        IU
#
#   vitamin_a_rae carotene_alpha carotene_beta cryptoxanthin_beta  \
# 0           mcg            mcg           mcg                mcg
#
#   lutein_zeaxanthin lucopene vitamin_b12 vitamin_b6 vitamin_c vitamin_d  \
# 0               mcg                  mcg         mg        mg        IU
#
#   vitamin_e tocopherol_alpha vitamin_k calcium copper irom magnesium  \
# 0        mg               mg       mcg      mg     mg   mg        mg
#
#   manganese phosphorous potassium selenium zink protein alanine arginine  \
# 0        mg          mg        mg      mcg   mg       g       g        g
#
#   aspartic_acid cystine glutamic_acid glycine histidine hydroxyproline  \
# ...

# %%
units = units.mode()

# %%
for k in units:
    print(units[k].at[0])
# Out:
# g
#
# g
# g
# mg
# mg
# mg
# mcg
# mcg
# mg
# mg
# mg
# mg
# IU
# mcg
# mcg
# mcg
# mcg
# mcg
#
# mcg
# mg
# mg
# IU
# mg
# mg
# mcg
# mg
# mg
# mg
# mg
# mg
# mg
# mg
# mcg
# mg
# g
# g
# g
# g
# g
# g
# g
# g
#
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
# g
#
#
#
#
#
#
# g
# g
# g
# g
# mg
# g
# g
# mg
# mg
# g

# %%
units = units.replace('',np.nan)

# %%
units
# Out:
#   serving_size  calories total_fat saturated_fat cholesterol sodium choline  \
# 0            g       NaN         g             g          mg     mg      mg
#
#   folate folic_acid niacin pantothenic_acid riboflavin thiamin vitamin_a  \
# 0    mcg        mcg     mg               mg         mg      mg        IU
#
#   vitamin_a_rae carotene_alpha carotene_beta cryptoxanthin_beta  \
# 0           mcg            mcg           mcg                mcg
#
#   lutein_zeaxanthin  lucopene vitamin_b12 vitamin_b6 vitamin_c vitamin_d  \
# 0               mcg       NaN         mcg         mg        mg        IU
#
#   vitamin_e tocopherol_alpha vitamin_k calcium copper irom magnesium  \
# 0        mg               mg       mcg      mg     mg   mg        mg
#
#   manganese phosphorous potassium selenium zink protein alanine arginine  \
# 0        mg          mg        mg      mcg   mg       g       g        g
#
#   aspartic_acid cystine glutamic_acid glycine histidine  hydroxyproline  \
# ...

# %%
units = units.dropna(axis = 1)

# %%
units
# Out:
#   serving_size total_fat saturated_fat cholesterol sodium choline folate  \
# 0            g         g             g          mg     mg      mg    mcg
#
#   folic_acid niacin pantothenic_acid riboflavin thiamin vitamin_a  \
# 0        mcg     mg               mg         mg      mg        IU
#
#   vitamin_a_rae carotene_alpha carotene_beta cryptoxanthin_beta  \
# 0           mcg            mcg           mcg                mcg
#
#   lutein_zeaxanthin vitamin_b12 vitamin_b6 vitamin_c vitamin_d vitamin_e  \
# 0               mcg         mcg         mg        mg        IU        mg
#
#   tocopherol_alpha vitamin_k calcium copper irom magnesium manganese  \
# 0               mg       mcg      mg     mg   mg        mg        mg
#
#   phosphorous potassium selenium zink protein alanine arginine aspartic_acid  \
# 0          mg        mg      mcg   mg       g       g        g             g
#
#   cystine glutamic_acid glycine histidine isoleucine leucine lysine  \
# ...

# %%
new_idx = {k:k+'_'+units[k].at[0] for k in units}

# %%
new_idx
# Out:
# {'serving_size': 'serving_size_g',
#  'total_fat': 'total_fat_g',
#  'saturated_fat': 'saturated_fat_g',
#  'cholesterol': 'cholesterol_mg',
#  'sodium': 'sodium_mg',
#  'choline': 'choline_mg',
#  'folate': 'folate_mcg',
#  'folic_acid': 'folic_acid_mcg',
#  'niacin': 'niacin_mg',
#  'pantothenic_acid': 'pantothenic_acid_mg',
#  'riboflavin': 'riboflavin_mg',
#  'thiamin': 'thiamin_mg',
#  'vitamin_a': 'vitamin_a_IU',
#  'vitamin_a_rae': 'vitamin_a_rae_mcg',
#  'carotene_alpha': 'carotene_alpha_mcg',
#  'carotene_beta': 'carotene_beta_mcg',
#  'cryptoxanthin_beta': 'cryptoxanthin_beta_mcg',
#  'lutein_zeaxanthin': 'lutein_zeaxanthin_mcg',
#  'vitamin_b12': 'vitamin_b12_mcg',
#  'vitamin_b6': 'vitamin_b6_mg',
#  'vitamin_c': 'vitamin_c_mg',
#  'vitamin_d': 'vitamin_d_IU',
#  'vitamin_e': 'vitamin_e_mg',
#  'tocopherol_alpha': 'tocopherol_alpha_mg',
#  'vitamin_k': 'vitamin_k_mcg',
#  'calcium': 'calcium_mg',
#  'copper': 'copper_mg',
#  'irom': 'irom_mg',
# ...

# %%
nutrition.rename(columns = new_idx,inplace =True)

# %%
nutrition = nutrition.replace('[a-zA-Z]','', regex=True).astype(float)

# %%
nutrition.info(verbose = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8789 entries, Cornstarch to Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round
# Columns: 75 entries, serving_size_g to water_g
# dtypes: float64(75)
# memory usage: 5.3+ MB

# %%
nutrition.total_fat_g.sum()
# Out:
# 92784.20000000001

# %%
nutrition.filter(like = 'Octopus',axis = 0)
# Out:
#                          serving_size_g  calories  total_fat_g  \
# name
# Octopus (Alaska Native)           100.0      56.0          0.8
#
#                          saturated_fat_g  cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)              0.2            41.0        0.0
#
#                          choline_mg  folate_mcg  folic_acid_mcg  niacin_mg  \
# name
# Octopus (Alaska Native)         0.0         0.0             0.0        2.0
#
#                          pantothenic_acid_mg  riboflavin_mg  thiamin_mg  \
# name
# Octopus (Alaska Native)                  0.0           0.04        0.03
#
#                          vitamin_a_IU  vitamin_a_rae_mcg  carotene_alpha_mcg  \
# name
# Octopus (Alaska Native)           0.0                0.0                 0.0
#
#                          carotene_beta_mcg  cryptoxanthin_beta_mcg  \
# name
# Octopus (Alaska Native)                0.0                     0.0
#
# ...

# %%
nutrition.filter(like = 'octopus',axis=0)
# Out:
#                                                serving_size_g  calories  \
# name
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
#                                                choline_mg  folate_mcg  \
# name
# Mollusks, raw, common, octopus                       65.0        16.0
# Mollusks, moist heat, cooked, common, octopus        81.0        24.0
#
# ...

# %%
nutrition.filter(regex = '[Oo]ctopus',axis = 0)
# Out:
#                                                serving_size_g  calories  \
# name
# Octopus (Alaska Native)                                 100.0      56.0
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Octopus (Alaska Native)                                0.8              0.2
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)                                  41.0        0.0
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
# ...

# %%
nutrition.filter(regex = '(?i)octopus',axis = 0)
# Out:
#                                                serving_size_g  calories  \
# name
# Octopus (Alaska Native)                                 100.0      56.0
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0
#
#                                                total_fat_g  saturated_fat_g  \
# name
# Octopus (Alaska Native)                                0.8              0.2
# Mollusks, raw, common, octopus                         1.0              0.2
# Mollusks, moist heat, cooked, common, octopus          2.1              0.5
#
#                                                cholesterol_mg  sodium_mg  \
# name
# Octopus (Alaska Native)                                  41.0        0.0
# Mollusks, raw, common, octopus                           48.0      230.0
# Mollusks, moist heat, cooked, common, octopus            96.0      460.0
#
# ...

# %%
nutrition.filter(regex = '[Oo]ctopus',axis = 0)\
         .filter(items = ['cholesterol_mg','saturated_fat_g','serving_size_g','calories'],axis =1)
# Out:
#                                                cholesterol_mg  \
# name
# Octopus (Alaska Native)                                  41.0
# Mollusks, raw, common, octopus                           48.0
# Mollusks, moist heat, cooked, common, octopus            96.0
#
#                                                saturated_fat_g  \
# name
# Octopus (Alaska Native)                                    0.2
# Mollusks, raw, common, octopus                             0.2
# Mollusks, moist heat, cooked, common, octopus              0.5
#
#                                                serving_size_g  calories
# name
# Octopus (Alaska Native)                                 100.0      56.0
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0

# %%
nutrition.filter(regex = '[Oo]ctopus',axis = 0)\
         .loc[:,['cholesterol_mg','saturated_fat_g','serving_size_g','calories']]
# Out:
#                                                cholesterol_mg  \
# name
# Octopus (Alaska Native)                                  41.0
# Mollusks, raw, common, octopus                           48.0
# Mollusks, moist heat, cooked, common, octopus            96.0
#
#                                                saturated_fat_g  \
# name
# Octopus (Alaska Native)                                    0.2
# Mollusks, raw, common, octopus                             0.2
# Mollusks, moist heat, cooked, common, octopus              0.5
#
#                                                serving_size_g  calories
# name
# Octopus (Alaska Native)                                 100.0      56.0
# Mollusks, raw, common, octopus                          100.0      82.0
# Mollusks, moist heat, cooked, common, octopus           100.0     164.0

# %%
nutrition.total_fat_g.sort_values()
# Out:
# name
# Gravy, fat free, slow roast, chicken, FRANCO-AMERICAN                      0.0
# Alcoholic beverage, 90 proof, gin, distilled                               0.0
# Beverages, Diet Cranberry Juice, OCEAN SPRAY                               0.0
# PACE, Dry Taco Seasoning Mix                                               0.0
# Soup, condensed, canned, beef broth bouillon and consomme                  0.0
#                                                                          ...
# Oil, fully hydrogenated, soy, industrial                                 100.0
# Oil, salad or cooking, sesame                                            100.0
# Oil, grapeseed                                                           100.0
# Oil, filling fat (non-hydrogenated), palm and palm kernel, industrial    100.0
# Shortening household soybean (hydrogenated) and palm                     100.0
# Name: total_fat_g, Length: 8789, dtype: float64

# %%
nutrition.sort_values(by = 'cholesterol_mg',ascending = False).head(15)
# Out:
#                                                     serving_size_g  calories  \
# name
# Veal, braised, cooked, brain, variety meats and...           100.0     136.0
# Beef, simmered, cooked, brain, variety meats an...           100.0     151.0
# Beef, raw, brain, variety meats and by-products              100.0     143.0
# Lamb, soaked and fried, cooked, brains, importe...           100.0     154.0
# Pork, braised, cooked, brain, variety meats and...           100.0     138.0
# Lamb, pan-fried, cooked, brain, variety meats a...           100.0     273.0
# Egg, dried, yolk                                             100.0     669.0
# Pork, raw, brain, variety meats and by-products...           100.0     127.0
# Veal, pan-fried, cooked, brain, variety meats a...           100.0     213.0
# Lamb, raw, brains, imported, New Zealand                     100.0     118.0
# Lamb, braised, cooked, brain, variety meats and...           100.0     145.0
# ...

# %%
nutrition.sort_values(by = ['cholesterol_mg','sodium_mg'],ascending = [False,True])
# Out:
#                                                     serving_size_g  calories  \
# name
# Beef, simmered, cooked, brain, variety meats an...           100.0     151.0
# Veal, braised, cooked, brain, variety meats and...           100.0     136.0
# Beef, raw, brain, variety meats and by-products              100.0     143.0
# Lamb, soaked and fried, cooked, brains, importe...           100.0     154.0
# Pork, braised, cooked, brain, variety meats and...           100.0     138.0
# ...                                                            ...       ...
# Leavening agents, sodium aluminum sulfate, doub...           100.0      53.0
# Seasoning mix, coriander & annatto, sazon, dry               100.0       0.0
# Desserts, unsweetened, tablets, rennin                       100.0      84.0
# Leavening agents, baking soda                                100.0       0.0
# Salt, table                                                  100.0       0.0
#
# ...

# %%
nutrition.loc['Beef, simmered, cooked, brain, variety meats and by-products'].filter(like = '_g',axis=0).sort_values(ascending = False)
# Out:
# serving_size_g                   100.000
# water_g                           74.860
# protein_g                         11.670
# total_fat_g                       11.000
# fat_g                             10.530
# saturated_fat_g                    2.400
# saturated_fatty_acids_g            2.394
# monounsaturated_fatty_acids_g      1.882
# polyunsaturated_fatty_acids_g      1.632
# carbohydrate_g                     1.480
# ash_g                              1.460
# threonine_g                        0.000
# alcohol_g                          0.000
# sugars_g                           0.000
# fiber_g                            0.000
# valine_g                           0.000
# tyrosine_g                         0.000
# tryptophan_g                       0.000
# serine_g                           0.000
# phenylalanine_g                    0.000
# methionine_g                       0.000
# lysine_g                           0.000
# leucine_g                          0.000
# ...

# %%
nutrition
# Out:
#                                                     serving_size_g  calories  \
# name
# Cornstarch                                                   100.0     381.0
# Nuts, pecans                                                 100.0     691.0
# Eggplant, raw                                                100.0      25.0
# Teff, uncooked                                               100.0     367.0
# Sherbet, orange                                              100.0     144.0
# ...                                                            ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     125.0
# Lamb, cooked, separable lean only, composite of...           100.0     206.0
# Lamb, raw, separable lean and fat, composite of...           100.0     277.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
#
# ...

# %%
nutrition.calories.head(10)
# Out:
# name
# Cornstarch            381.0
# Nuts, pecans          691.0
# Eggplant, raw          25.0
# Teff, uncooked        367.0
# Sherbet, orange       144.0
# Cauliflower, raw       25.0
# Taro leaves, raw       42.0
# Lamb, raw, ground     282.0
# Cheese, camembert     300.0
# Vegetarian fillets    290.0
# Name: calories, dtype: float64

# %%
nutrition.calories.between(30,50)
# Out:
# name
# Cornstarch                                                                                            False
# Nuts, pecans                                                                                          False
# Eggplant, raw                                                                                         False
# Teff, uncooked                                                                                        False
# Sherbet, orange                                                                                       False
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    False
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# ...

# %%
nutrition[nutrition.calories.between(30,50)].sample(4)
# Out:
#                                                     serving_size_g  calories  \
# name
# Acerola, raw, (west indian cherry)                           100.0      32.0
# Fruit salad, solids and liquids, water pack, ca...           100.0      30.0
# Guava sauce, cooked                                          100.0      36.0
# Lemonade, prepared with water, white, frozen co...           100.0      40.0
#
#                                                     total_fat_g  \
# name
# Acerola, raw, (west indian cherry)                          0.3
# Fruit salad, solids and liquids, water pack, ca...          0.1
# Guava sauce, cooked                                         0.1
# Lemonade, prepared with water, white, frozen co...          0.0
#
#                                                     saturated_fat_g  \
# name
# Acerola, raw, (west indian cherry)                              0.1
# Fruit salad, solids and liquids, water pack, ca...              NaN
# ...

# %%
nutrition.max()
# Out:
# serving_size_g      100.0
# calories            902.0
# total_fat_g         100.0
# saturated_fat_g      96.0
# cholesterol_mg     3100.0
#                     ...
# alcohol_g            42.5
# ash_g                99.8
# caffeine_mg        5714.0
# theobromine_mg     2634.0
# water_g             100.0
# Length: 75, dtype: float64

# %%
nutrition.max(axis  =1)
# Out:
# name
# Cornstarch                                                                                            381.0
# Nuts, pecans                                                                                          691.0
# Eggplant, raw                                                                                         229.0
# Teff, uncooked                                                                                        429.0
# Sherbet, orange                                                                                       144.0
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    311.0
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    246.0
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    277.0
# ...

# %%
nutrition.min()
# Out:
# serving_size_g     100.0
# calories             0.0
# total_fat_g          0.0
# saturated_fat_g      0.1
# cholesterol_mg       0.0
#                    ...
# alcohol_g            0.0
# ash_g                0.0
# caffeine_mg          0.0
# theobromine_mg       0.0
# water_g              0.0
# Length: 75, dtype: float64

# %%
nutrition.min(axis = 1)
# Out:
# name
# Cornstarch                                                                                            0.0
# Nuts, pecans                                                                                          0.0
# Eggplant, raw                                                                                         0.0
# Teff, uncooked                                                                                        0.0
# Sherbet, orange                                                                                       0.0
#                                                                                                      ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    0.0
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    0.0
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    0.0
# ...

# %%
nutrition.potassium_mg.max()
# Out:
# 16500.0

# %%
nutrition.potassium_mg.idxmax()
# Out:
# 'Leavening agents, cream of tartar'

# %%
nutrition.potassium_mg.sort_values(ascending = False).head(10)
# Out:
# name
# Leavening agents, cream of tartar                         16500.0
# Leavening agents, low-sodium, baking powder               10100.0
# Parsley, freeze-dried                                      6300.0
# Beverages, unsweetened, decaffeinated, instant, tea        6040.0
# Beverages, powder, unsweetened, instant, tea               6040.0
# Spices, dried, chervil                                     4740.0
# Spices, dried, coriander leaf                              4466.0
# Celery flakes, dried                                       4388.0
# Beverages, powder, regular, instant, coffee                3535.0
# Beverages, half the caffeine, regular, instant, coffee     3535.0
# Name: potassium_mg, dtype: float64

# %%
K_to_NA = (nutrition.potassium_mg.replace(0,1)/nutrition.sodium_mg.replace(0,1))\
        .sort_values(ascending = False)

# %%
K_to_NA.head(10)
# Out:
# name
# Peanut flour, low fat                                           1358.0
# Nuts, raw, pistachio nuts                                       1025.0
# Beverages, reduced calorie, with whitener, instant, coffee       909.0
# Soybeans, raw, mature seeds                                      898.5
# Soy meal, raw, defatted                                          830.0
# Babyfood, dry, with bananas, rice, cereal                        769.0
# Nuts, without salt added, dry roasted, hazelnuts or filberts     755.0
# Soy protein concentrate, produced by alcohol extraction          734.0
# Nuts, almonds                                                    733.0
# Nuts, full fat, acorn flour                                      712.0
# dtype: float64

# %%
K_to_NA[K_to_NA.between(14,18)].sample(20)
# Out:
# name
# Apple juice, with added ascorbic acid, diluted with 3 volume water, unsweetened, frozen concentrate                 18.000000
# Peppers, without salt, drained, boiled, chopped, frozen, green, sweet                                               18.000000
# Cereals, without salt, cooked with water (includes boiling and microwaving), unenriched, regular and quick, oats    17.500000
# Fish, raw, wild, rainbow, trout                                                                                     15.516129
# Fruit cocktail, solids and liquids, heavy syrup, canned, (peach and pineapple and pear and grape and cherry)        14.666667
# Waterchestnuts, solids and liquids, canned, chinese                                                                 14.750000
# Corn, raw, yellow, sweet                                                                                            18.000000
# ...

# %%
nutrition
# Out:
#                                                     serving_size_g  calories  \
# name
# Cornstarch                                                   100.0     381.0
# Nuts, pecans                                                 100.0     691.0
# Eggplant, raw                                                100.0      25.0
# Teff, uncooked                                               100.0     367.0
# Sherbet, orange                                              100.0     144.0
# ...                                                            ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     125.0
# Lamb, cooked, separable lean only, composite of...           100.0     206.0
# Lamb, raw, separable lean and fat, composite of...           100.0     277.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
#
# ...

# %%
nutrition.vitamin_b12_mcg.nlargest(10)
# Out:
# name
# Mollusks, moist heat, cooked, mixed species, clam                                   98.89
# Beef, boiled, cooked, variety meats and by-products liver, imported, New Zealand    96.00
# Lamb, raw, liver, variety meats and by-products                                     90.05
# Lamb, pan-fried, cooked, liver, variety meats and by-products                       85.70
# Veal, braised, cooked, liver, variety meats and by-products                         84.60
# Beef, raw, liver, variety meats and by-products, imported, New Zealand              84.50
# Beef, pan-fried, cooked, liver, variety meats and by-products                       83.13
# Lamb, braised, cooked, kidneys, variety meats and by-products                       78.90
# Lamb, braised, cooked, liver, variety meats and by-products                         76.50
# Veal, pan-fried, cooked, liver, variety meats and by-products                       72.50
# Name: vitamin_b12_mcg, dtype: float64

# %%
eggplant = nutrition.filter(regex = '(?i)eggplant',axis = 0)

# %%
eggplant.sodium_mg.max()
# Out:
# 1674.0

# %%
eggplant.sodium_mg.idxmax()
# Out:
# 'Eggplant, pickled'

# %%
eggplant.sodium_mg
# Out:
# name
# Eggplant, raw                                         2.0
# Eggplant, pickled                                  1674.0
# Eggplant, with salt, drained, boiled, cooked        239.0
# Eggplant, without salt, drained, boiled, cooked       1.0
# Name: sodium_mg, dtype: float64

# %%
nutrition.sample(4).sample(2,axis=1)
# Out:
#                                                     caffeine_mg  lucopene
# name
# Gravy, mix, dry, onion                                      0.0       0.0
# MORI-NU, extra firm, silken, Tofu                           0.0       0.0
# Elk, raw (Shoshone Bannock), eye of round, roas...          0.0       0.0
# Beans, microwaved, green, snap                              0.0       0.0

# %%
nutrition.dropna(how='any',axis=0,inplace = True)

# %%
nona = nutrition.dropna(how='any')

# %%
m = nona.vitamin_c_mg.mean()

# %%
nona.vitamin_c_mg.between(6,7)
# Out:
# name
# Nuts, pecans                                                                                          False
# Teff, uncooked                                                                                        False
# Sherbet, orange                                                                                       False
# Cauliflower, raw                                                                                      False
# Taro leaves, raw                                                                                      False
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    False
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# ...

# %%
nona[nona.vitamin_c_mg.between(6,7)]
# Out:
#                                                     serving_size_g  calories  \
# name
# Gravy, mix, dry, onion                                       100.0     322.0
# Snacks, banana chips                                         100.0     519.0
# Melon balls, frozen                                          100.0      33.0
# Babyfood, cookies                                            100.0     433.0
# Corn, raw, white, sweet                                      100.0      86.0
# ...                                                            ...       ...
# Cereals ready-to-eat, KELLOGG'S Low Fat Granola...           100.0     389.0
# Potatoes, water and margarine added, prepared f...           100.0     116.0
# Potatoes, whole milk and butter added, prepared...           100.0     108.0
# Potatoes, without salt, heated in oven, prepare...           100.0     333.0
# Infant formula, with ARA and DHA, SENSITIVE (LA...           100.0      68.0
#
# ...

# %%
nona.vitamin_c_mg.between(20,40)
# Out:
# name
# Nuts, pecans                                                                                          False
# Teff, uncooked                                                                                        False
# Sherbet, orange                                                                                       False
# Cauliflower, raw                                                                                      False
# Taro leaves, raw                                                                                      False
#                                                                                                       ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round    False
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand    False
# ...

# %%
nona[nona.vitamin_c_mg.between(20,40)]
# Out:
#                                                     serving_size_g  calories  \
# name
# Broccoli, raw, chinese                                       100.0      30.0
# Broccoli raab, cooked                                        100.0      33.0
# Horseradish, prepared                                        100.0      48.0
# Spices, white, pepper                                        100.0     296.0
# Dandelion greens, raw                                        100.0      45.0
# ...                                                            ...       ...
# Beverages, fortified, ready to drink, milk and ...           100.0     101.0
# Cereals ready-to-eat, Peanut Butter, Multi Grai...           100.0     390.0
# Infant formula, with ARA and DHA, ready-to-feed...           100.0      78.0
# Cereals ready-to-eat, KELLOGG'S SMART START Str...           100.0     371.0
# Infant formula, with ARA and DHA, ready-to-feed...           100.0      71.0
#
# ...

# %%
nona[nona.vitamin_c_mg.between(20,40)].calories.idxmin()
# Out:
# 'Asparagus, with salt, drained, boiled, cooked, frozen'

# %%
nona[nona.vitamin_c_mg.between(20,40)].calories.min()
# Out:
# 18.0

# %%
nutrition
# Out:
#                                                     serving_size_g  calories  \
# name
# Nuts, pecans                                                 100.0     691.0
# Teff, uncooked                                               100.0     367.0
# Sherbet, orange                                              100.0     144.0
# Cauliflower, raw                                             100.0      25.0
# Taro leaves, raw                                             100.0      42.0
# ...                                                            ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     125.0
# Lamb, cooked, separable lean only, composite of...           100.0     206.0
# Lamb, raw, separable lean and fat, composite of...           100.0     277.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
# Beef, raw, all grades, trimmed to 0" fat, separ...           100.0     121.0
#
# ...

# %%
mp2sd = m + nona.vitamin_c_mg.std()*2

# %%
mp3sd = m + nona.vitamin_c_mg.std()*3

# %%
print(mp2sd,mp3sd)
# Out:
# 97.7621389681903 143.86652419058245

# %%
result = nona[nona.vitamin_c_mg.between(mp2sd,mp3sd)]

# %%
result.vitamin_c_mg.describe()
# Out:
# count     17.000000
# mean     119.617647
# std        9.190772
# min      101.800000
# 25%      118.000000
# 50%      120.000000
# 75%      120.000000
# max      138.000000
# Name: vitamin_c_mg, dtype: float64
