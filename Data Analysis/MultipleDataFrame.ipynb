# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
party_url = 'https://andybek.com/pandas-party'

# %%
party = pd.read_csv(party_url)

# %%
eng = pd.read_csv("C:/Users/rajen/Data Analysis/eng.csv")

# %%
state = pd.read_csv("C:/Users/rajen/Data Analysis/state.csv")

# %%
liberal= pd.read_csv("C:/Users/rajen/Data Analysis/liberal_arts.csv")

# %%
ivies = pd.read_csv("C:/Users/rajen/Data Analysis/ivies.csv")

# %%
eng
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
state
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 170                    Austin Peay State University       State
# 171                      Pittsburg State University       State
# 172                        Southern Utah University       State
# 173             Montana State University - Billings       State
# 174                    Black Hills State University       State
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $59,900.00              $112,000.00
# 1              $52,700.00              $103,000.00
# ...

# %%
party
# Out:
#                                           School Name School Type  \
# 0   University of Illinois at Urbana-Champaign (UIUC)       Party
# 1                University of Maryland, College Park       Party
# 2      University of California, Santa Barbara (UCSB)       Party
# 3                   University of Texas (UT) - Austin       Party
# 4       State University of New York (SUNY) at Albany       Party
# 5                          University of Florida (UF)       Party
# 6                    Louisiana State University (LSU)       Party
# 7                         University of Georgia (UGA)       Party
# 8                 Pennsylvania State University (PSU)       Party
# 9                      Arizona State University (ASU)       Party
# 10               Indiana University (IU), Bloomington       Party
# 11                            University of Iowa (UI)       Party
# 12                             Randolph-Macon College       Party
# ...

# %%
liberal
# Out:
#                                       School Name   School Type  \
# 0                             Bucknell University  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 2                                 Amherst College  Liberal Arts
# 3                               Lafayette College  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 6                              Occidental College  Liberal Arts
# 7                   Washington and Lee University  Liberal Arts
# 8                              Swarthmore College  Liberal Arts
# 9                                Davidson College  Liberal Arts
# 10                               Carleton College  Liberal Arts
# 11                               Williams College  Liberal Arts
# 12                                 Pomona College  Liberal Arts
# 13  Wesleyan University (Middletown, Connecticut)  Liberal Arts
# ...

# %%
ivies
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
dfs = [eng, state,liberal,party,ivies]

# %%
pd.concat(dfs)
# Out:
#                                      School Name  School Type  \
# 0    Massachusetts Institute of Technology (MIT)  Engineering
# 1       California Institute of Technology (CIT)  Engineering
# 2                            Harvey Mudd College  Engineering
# 3   Polytechnic University of New York, Brooklyn  Engineering
# 4                                   Cooper Union  Engineering
# ..                                           ...          ...
# 3                             Harvard University   Ivy League
# 4                     University of Pennsylvania   Ivy League
# 5                             Cornell University   Ivy League
# 6                               Brown University   Ivy League
# 7                            Columbia University   Ivy League
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# ...

# %%
for i in dfs:
    print(i.shape)
# Out:
# (19, 4)
# (175, 4)
# (47, 4)
# (20, 4)
# (8, 4)

# %%
pd.concat(dfs).duplicated(subset = ['School Name'],keep='first')
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
#      ...
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# Length: 269, dtype: bool

# %%
pd.concat(dfs)[pd.concat(dfs).duplicated(subset = ['School Name'],keep='first')]
# Out:
#                                           School Name School Type  \
# 0   University of Illinois at Urbana-Champaign (UIUC)       Party
# 1                University of Maryland, College Park       Party
# 2      University of California, Santa Barbara (UCSB)       Party
# 3                   University of Texas (UT) - Austin       Party
# 4       State University of New York (SUNY) at Albany       Party
# 5                          University of Florida (UF)       Party
# 6                    Louisiana State University (LSU)       Party
# 7                         University of Georgia (UGA)       Party
# 8                 Pennsylvania State University (PSU)       Party
# 9                      Arizona State University (ASU)       Party
# 10               Indiana University (IU), Bloomington       Party
# 11                            University of Iowa (UI)       Party
# 12                             Randolph-Macon College       Party
# ...

# %%
pd.concat(dfs).drop_duplicates(subset='School Name',keep='first')
# Out:
#                                      School Name  School Type  \
# 0    Massachusetts Institute of Technology (MIT)  Engineering
# 1       California Institute of Technology (CIT)  Engineering
# 2                            Harvey Mudd College  Engineering
# 3   Polytechnic University of New York, Brooklyn  Engineering
# 4                                   Cooper Union  Engineering
# ..                                           ...          ...
# 3                             Harvard University   Ivy League
# 4                     University of Pennsylvania   Ivy League
# 5                             Cornell University   Ivy League
# 6                               Brown University   Ivy League
# 7                            Columbia University   Ivy League
#
#    Starting Median Salary Mid-Career Median Salary
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# ...

# %%
school = pd.concat(dfs,ignore_index=True).drop_duplicates(subset='School Name',keep='first')

# %%
 school
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                            Harvard University   Ivy League
# 265                    University of Pennsylvania   Ivy League
# 266                            Cornell University   Ivy League
# 267                              Brown University   Ivy League
# 268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# 2              $71,800.00              $122,000.00
# ...

# %%
school.reset_index(inplace = True)

# %%
school.index.unique()
# Out:
# RangeIndex(start=0, stop=249, step=1)

# %%
schools = pd.concat(dfs,ignore_index=True).drop_duplicates(subset=['School Name'],keep='first')

# %%
schools
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                            Harvard University   Ivy League
# 265                    University of Pennsylvania   Ivy League
# 266                            Cornell University   Ivy League
# 267                              Brown University   Ivy League
# 268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# 2              $71,800.00              $122,000.00
# ...

# %%
schools.set_index(['School Name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 schools.set_index(['School Name'])
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# ...

# %%
schools.reset_index(inplace = True)

# %%
schools
# Out:
#      index                                   School Name  School Type  \
# 0        0   Massachusetts Institute of Technology (MIT)  Engineering
# 1        1      California Institute of Technology (CIT)  Engineering
# 2        2                           Harvey Mudd College  Engineering
# 3        3  Polytechnic University of New York, Brooklyn  Engineering
# 4        4                                  Cooper Union  Engineering
# ..     ...                                           ...          ...
# 244    264                            Harvard University   Ivy League
# 245    265                    University of Pennsylvania   Ivy League
# 246    266                            Cornell University   Ivy League
# 247    267                              Brown University   Ivy League
# 248    268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $72,200.00              $126,000.00
# ...

# %%
pd.concat([ivies,eng],ignore_index=True).drop_duplicates(subset=['School Name'],keep='first')
# Out:
#                                           School Name  School Type  \
# 0                                   Dartmouth College   Ivy League
# 1                                Princeton University   Ivy League
# 2                                     Yale University   Ivy League
# 3                                  Harvard University   Ivy League
# 4                          University of Pennsylvania   Ivy League
# 5                                  Cornell University   Ivy League
# 6                                    Brown University   Ivy League
# 7                                 Columbia University   Ivy League
# 8         Massachusetts Institute of Technology (MIT)  Engineering
# 9            California Institute of Technology (CIT)  Engineering
# 10                                Harvey Mudd College  Engineering
# 11       Polytechnic University of New York, Brooklyn  Engineering
# 12                                       Cooper Union  Engineering
# ...

# %%
new_df = pd.concat([ivies,eng],keys = ['Ivy_league','Engineering_school'])

# %%
new_df
# Out:
#                                                              School Name  \
# Ivy_league         0                                   Dartmouth College
#                    1                                Princeton University
#                    2                                     Yale University
#                    3                                  Harvard University
#                    4                          University of Pennsylvania
#                    5                                  Cornell University
#                    6                                    Brown University
#                    7                                 Columbia University
# Engineering_school 0         Massachusetts Institute of Technology (MIT)
#                    1            California Institute of Technology (CIT)
#                    2                                 Harvey Mudd College
#                    3        Polytechnic University of New York, Brooklyn
# ...

# %%
new_df.loc['Engineering_school',3]
# Out:
# School Name                 Polytechnic University of New York, Brooklyn
# School Type                                                  Engineering
# Starting Median Salary                                       $62,400.00
# Mid-Career Median Salary                                    $114,000.00
# Name: (Engineering_school, 3), dtype: object

# %%
schools
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 244                            Harvard University   Ivy League
# 245                    University of Pennsylvania   Ivy League
# 246                            Cornell University   Ivy League
# 247                              Brown University   Ivy League
# 248                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# 2              $71,800.00              $122,000.00
# ...

# %%
state.sort_values(['Starting Median Salary'],ascending = False)[:5].reset_index(drop = True)
# Out:
#                             School Name School Type Starting Median Salary  \
# 0    University of California, Berkeley       State            $59,900.00
# 1              Cal Poly San Luis Obispo       State            $57,200.00
# 2  University of Missouri - Rolla (UMR)       State            $57,100.00
# 3                 Binghamton University       State            $53,600.00
# 4      San Jose State University (SJSU)       State            $53,500.00
#
#   Mid-Career Median Salary
# 0             $112,000.00
# 1             $101,000.00
# 2              $95,800.00
# 3              $95,900.00
# 4              $95,600.00

# %%
ivies3 = ivies.sort_values(by=['Starting Median Salary'],ascending = False)[:6].reset_index(drop=True)

# %%
eng3 = eng.sort_values(by=['Starting Median Salary'],ascending = False)[:5].reset_index(drop=True)

# %%
pd.concat([ivies3,eng3],axis = 1)
# Out:
#                   School Name School Type Starting Median Salary  \
# 0        Princeton University  Ivy League            $66,500.00
# 1          Harvard University  Ivy League            $63,400.00
# 2  University of Pennsylvania  Ivy League            $60,900.00
# 3          Cornell University  Ivy League            $60,300.00
# 4         Columbia University  Ivy League            $59,400.00
# 5             Yale University  Ivy League            $59,100.00
#
#   Mid-Career Median Salary                                   School Name  \
# 0             $131,000.00       California Institute of Technology (CIT)
# 1             $124,000.00    Massachusetts Institute of Technology (MIT)
# 2             $120,000.00                            Harvey Mudd College
# 3             $110,000.00   Polytechnic University of New York, Brooklyn
# 4             $107,000.00                                   Cooper Union
# 5             $126,000.00                                            NaN
#
# ...

# %%
eng4 = eng.copy()

# %%
eng4['STEM'] = True

# %%
eng4
# Out:
#                                           School Name  School Type  \
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# 7              Rensselaer Polytechnic Institute (RPI)  Engineering
# 8                     Georgia Institute of Technology  Engineering
# 9                            Colorado School of Mines  Engineering
# 10                    Stevens Institute of Technology  Engineering
# 11             Illinois Institute of Technology (IIT)  Engineering
# 12                  Wentworth Institute of Technology  Engineering
# ...

# %%
pd.concat([ivies3,eng4])
# Out:
#                                           School Name  School Type  \
# 0                                Princeton University   Ivy League
# 1                                  Harvard University   Ivy League
# 2                          University of Pennsylvania   Ivy League
# 3                                  Cornell University   Ivy League
# 4                                 Columbia University   Ivy League
# 5                                     Yale University   Ivy League
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# ...

# %%
pd.concat([ivies3,eng4],join='inner')#default =outer
# Out:
#                                           School Name  School Type  \
# 0                                Princeton University   Ivy League
# 1                                  Harvard University   Ivy League
# 2                          University of Pennsylvania   Ivy League
# 3                                  Cornell University   Ivy League
# 4                                 Columbia University   Ivy League
# 5                                     Yale University   Ivy League
# 0         Massachusetts Institute of Technology (MIT)  Engineering
# 1            California Institute of Technology (CIT)  Engineering
# 2                                 Harvey Mudd College  Engineering
# 3        Polytechnic University of New York, Brooklyn  Engineering
# 4                                        Cooper Union  Engineering
# 5               Worcester Polytechnic Institute (WPI)  Engineering
# 6                    Carnegie Mellon University (CMU)  Engineering
# ...

# %%
pd.concat([eng4.head(6),ivies3],axis = 1)
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
# 5         Worcester Polytechnic Institute (WPI)  Engineering
#
#   Starting Median Salary Mid-Career Median Salary  STEM  \
# 0            $72,200.00              $126,000.00   True
# 1            $75,500.00              $123,000.00   True
# 2            $71,800.00              $122,000.00   True
# 3            $62,400.00              $114,000.00   True
# 4            $62,200.00              $114,000.00   True
# 5            $61,000.00              $114,000.00   True
#
#                   School Name School Type Starting Median Salary  \
# 0        Princeton University  Ivy League            $66,500.00
# ...

# %%
new_df2 = pd.concat([liberal, state],ignore_index = True,)

# %%
new_df2['School Name'].nunique()
# Out:
# 222

# %%
new_df2.shape
# Out:
# (222, 4)

# %%
new_df2.replace('[$,]','',regex = True,inplace = True)

# %%
new_df2['Starting Median Salary'].astype(float).mean()
# Out:
# 44469.36936936937

# %%
lib1 = liberal.replace('[$,]','',regex=True)
lib1['Mid-Career Median Salary'].astype(float).sort_values(ascending=False)[:3]
# Out:
# 0    110000.0
# 1    108000.0
# 2    107000.0
# Name: Mid-Career Median Salary, dtype: float64

# %%
st1 =state.replace('[$,]','',regex=True)
st1['Mid-Career Median Salary'].astype(float).sort_values(ascending=False)[:3]
# Out:
# 0    112000.0
# 1    103000.0
# 2    101000.0
# Name: Mid-Career Median Salary, dtype: float64

# %%
pd.concat([liberal.head(3),state.head(3)],keys = ['Liberal Arts','State'])a
# Out:
#                                        School Name   School Type  \
# Liberal Arts 0                 Bucknell University  Liberal Arts
#              1                  Colgate University  Liberal Arts
#              2                     Amherst College  Liberal Arts
# State        0  University of California, Berkeley         State
#              1        University of Virginia (UVA)         State
#              2            Cal Poly San Luis Obispo         State
#
#                Starting Median Salary Mid-Career Median Salary
# Liberal Arts 0            $54,100.00              $110,000.00
#              1            $52,800.00              $108,000.00
#              2            $54,500.00              $107,000.00
# State        0            $59,900.00              $112,000.00
#              1            $52,700.00              $103,000.00
#              2            $57,200.00              $101,000.00

# %%
pd.concat([liberal.head(3),state.head(3)],axis = 1).drop(['School Type','Starting Median Salary'],axis = 1)
# Out:
#            School Name Mid-Career Median Salary  \
# 0  Bucknell University             $110,000.00
# 1   Colgate University             $108,000.00
# 2      Amherst College             $107,000.00
#
#                           School Name Mid-Career Median Salary
# 0  University of California, Berkeley             $112,000.00
# 1        University of Virginia (UVA)             $103,000.00
# 2            Cal Poly San Luis Obispo             $101,000.00

# %%
new_df2
# Out:
#                              School Name   School Type Starting Median Salary  \
# 0                    Bucknell University  Liberal Arts              54100.00
# 1                     Colgate University  Liberal Arts              52800.00
# 2                        Amherst College  Liberal Arts              54500.00
# 3                      Lafayette College  Liberal Arts              53900.00
# 4                        Bowdoin College  Liberal Arts              48100.00
# ..                                   ...           ...                    ...
# 217         Austin Peay State University         State              37700.00
# 218           Pittsburg State University         State              40400.00
# 219             Southern Utah University         State              41900.00
# 220  Montana State University - Billings         State              37900.00
# 221         Black Hills State University         State              35300.00
#
#     Mid-Career Median Salary
# ...

# %%
regions = pd.read_csv("C:/Users/rajen/Data Analysis/regions.csv")

# %%
regions
# Out:
#                                       School Name        Region
# 0     Massachusetts Institute of Technology (MIT)  Northeastern
# 1        California Institute of Technology (CIT)    California
# 2                             Harvey Mudd College    California
# 3    Polytechnic University of New York, Brooklyn  Northeastern
# 4                                    Cooper Union  Northeastern
# ..                                            ...           ...
# 264                  Austin Peay State University      Southern
# 265                    Pittsburg State University    Midwestern
# 266                      Southern Utah University       Western
# 267           Montana State University - Billings       Western
# 268                  Black Hills State University    Midwestern
#
# [269 rows x 2 columns]

# %%
pd.merge(schools,regions,on ='School Name').reset_index(drop=True)
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                            Harvard University   Ivy League
# 265                    University of Pennsylvania   Ivy League
# 266                            Cornell University   Ivy League
# 267                              Brown University   Ivy League
# 268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0              $72,200.00              $126,000.00   Northeastern
# 1              $75,500.00              $123,000.00     California
# ...

# %%
schools
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                            Harvard University   Ivy League
# 265                    University of Pennsylvania   Ivy League
# 266                            Cornell University   Ivy League
# 267                              Brown University   Ivy League
# 268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# 2              $71,800.00              $122,000.00
# ...

# %%
income =  pd.read_csv("C:/Users/rajen/Data Analysis/mid_career_salaries.csv")

# %%
income
# Out:
#                                       school_name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 264                  Austin Peay State University
# 265                    Pittsburg State University
# 266                      Southern Utah University
# 267           Montana State University - Billings
# 268                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# ...

# %%
pd.merge(income,schools,left_on='school_name',right_on = 'School Name')
# Out:
#                                       school_name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 264                  Austin Peay State University
# 265                    Pittsburg State University
# 266                      Southern Utah University
# 267           Montana State University - Billings
# 268                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# ...

# %%
pd.merge(school,income,left_on='School Name',right_on='school_name')
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                            Harvard University   Ivy League
# 265                    University of Pennsylvania   Ivy League
# 266                            Cornell University   Ivy League
# 267                              Brown University   Ivy League
# 268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# ...

# %%
pd.merge(schools,income,left_on='School Name',right_on='school_name').drop(['school_name'],axis=1)
# Out:
#                                       School Name  School Type  \
# 0     Massachusetts Institute of Technology (MIT)  Engineering
# 1        California Institute of Technology (CIT)  Engineering
# 2                             Harvey Mudd College  Engineering
# 3    Polytechnic University of New York, Brooklyn  Engineering
# 4                                    Cooper Union  Engineering
# ..                                            ...          ...
# 264                            Harvard University   Ivy League
# 265                    University of Pennsylvania   Ivy League
# 266                            Cornell University   Ivy League
# 267                              Brown University   Ivy League
# 268                           Columbia University   Ivy League
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0              $72,200.00              $126,000.00
# 1              $75,500.00              $123,000.00
# ...

# %%
pd.merge(ivies,income,left_on = 'School Name',right_on = 'school_name',how = 'outer')
# Out:
#                     School Name School Type Starting Median Salary  \
# 0             Dartmouth College  Ivy League            $58,000.00
# 1          Princeton University  Ivy League            $66,500.00
# 2               Yale University  Ivy League            $59,100.00
# 3            Harvard University  Ivy League            $63,400.00
# 4    University of Pennsylvania  Ivy League            $60,900.00
# ..                          ...         ...                    ...
# 264                         NaN         NaN                    NaN
# 265                         NaN         NaN                    NaN
# 266                         NaN         NaN                    NaN
# 267                         NaN         NaN                    NaN
# 268                         NaN         NaN                    NaN
#
#     Mid-Career Median Salary                          school_name  \
# 0               $134,000.00                     Dartmouth College
# ...

# %%
ivies
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary
# 0             $134,000.00
# 1             $131,000.00
# 2             $126,000.00
# 3             $124,000.00
# 4             $120,000.00
# 5             $110,000.00
# 6             $109,000.00
# 7             $107,000.00

# %%
income
# Out:
#                                       school_name  \
# 0     Massachusetts Institute of Technology (MIT)
# 1        California Institute of Technology (CIT)
# 2                             Harvey Mudd College
# 3    Polytechnic University of New York, Brooklyn
# 4                                    Cooper Union
# ..                                            ...
# 264                  Austin Peay State University
# 265                    Pittsburg State University
# 266                      Southern Utah University
# 267           Montana State University - Billings
# 268                  Black Hills State University
#
#     Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                         $76,800.00                        $99,200.00
# 1                                 NaN                      $104,000.00
# 2                                 NaN                       $96,000.00
# 3                         $66,800.00                        $94,300.00
# ...

# %%
pd.merge(ivies,income,left_on='School Name',right_on='school_name',how='left')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary                 school_name  \
# 0             $134,000.00            Dartmouth College
# 1             $131,000.00         Princeton University
# 2             $126,000.00              Yale University
# 3             $124,000.00           Harvard University
# 4             $120,000.00   University of Pennsylvania
# ...

# %%
pd.merge(ivies,regions,how='right')
# Out:
#                                       School Name School Type  \
# 0     Massachusetts Institute of Technology (MIT)         NaN
# 1        California Institute of Technology (CIT)         NaN
# 2                             Harvey Mudd College         NaN
# 3    Polytechnic University of New York, Brooklyn         NaN
# 4                                    Cooper Union         NaN
# ..                                            ...         ...
# 264                  Austin Peay State University         NaN
# 265                    Pittsburg State University         NaN
# 266                      Southern Utah University         NaN
# 267           Montana State University - Billings         NaN
# 268                  Black Hills State University         NaN
#
#     Starting Median Salary Mid-Career Median Salary        Region
# 0                      NaN                      NaN  Northeastern
# 1                      NaN                      NaN    California
# ...

# %%
pd.merge(ivies,regions,how='left')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
pd.merge(ivies,income,left_on='School Name',right_on='school_name',how='right')
# Out:
#     School Name School Type Starting Median Salary Mid-Career Median Salary  \
# 0           NaN         NaN                    NaN                      NaN
# 1           NaN         NaN                    NaN                      NaN
# 2           NaN         NaN                    NaN                      NaN
# 3           NaN         NaN                    NaN                      NaN
# 4           NaN         NaN                    NaN                      NaN
# ..          ...         ...                    ...                      ...
# 264         NaN         NaN                    NaN                      NaN
# 265         NaN         NaN                    NaN                      NaN
# 266         NaN         NaN                    NaN                      NaN
# 267         NaN         NaN                    NaN                      NaN
# 268         NaN         NaN                    NaN                      NaN
#
#                                       school_name  \
# ...

# %%
pd.merge(ivies,regions,how='inner',on='School Name')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
pd.merge(state,regions,how='inner',on='School Name').sort_values(['School Name'])
# Out:
#                            School Name School Type Starting Median Salary  \
# 169       Appalachian State University       State            $40,400.00
# 58      Arizona State University (ASU)       State            $47,400.00
# 57      Arizona State University (ASU)       State            $47,400.00
# 184    Arkansas State University (ASU)       State            $38,700.00
# 48                   Auburn University       State            $45,400.00
# ..                                 ...         ...                    ...
# 107     West Virginia University (WVU)       State            $43,100.00
# 108     West Virginia University (WVU)       State            $43,100.00
# 175        Western Carolina University       State            $36,900.00
# 131  Western Michigan University (WMU)       State            $42,300.00
# 122      Western Washington University       State            $42,700.00
#
#     Mid-Career Median Salary      Region
# 169              $69,100.00     Southern
# ...

# %%
pd.merge(state,regions.drop_duplicates(subset='School Name',keep='first'))
# Out:
#                                         School Name School Type  \
# 0                University of California, Berkeley       State
# 1                      University of Virginia (UVA)       State
# 2                          Cal Poly San Luis Obispo       State
# 3    University of California at Los Angeles (UCLA)       State
# 4        University of California, San Diego (UCSD)       State
# ..                                              ...         ...
# 170                    Austin Peay State University       State
# 171                      Pittsburg State University       State
# 172                        Southern Utah University       State
# 173             Montana State University - Billings       State
# 174                    Black Hills State University       State
#
#     Starting Median Salary Mid-Career Median Salary      Region
# 0              $59,900.00              $112,000.00   California
# 1              $52,700.00              $103,000.00     Southern
# ...

# %%
ivies4 = ivies.set_index('School Name')

# %%
ivies4
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Dartmouth College           Ivy League            $58,000.00
# Princeton University        Ivy League            $66,500.00
# Yale University             Ivy League            $59,100.00
# Harvard University          Ivy League            $63,400.00
# University of Pennsylvania  Ivy League            $60,900.00
# Cornell University          Ivy League            $60,300.00
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
#
#                            Mid-Career Median Salary
# School Name
# Dartmouth College                      $134,000.00
# Princeton University                   $131,000.00
# Yale University                        $126,000.00
# Harvard University                     $124,000.00
# University of Pennsylvania             $120,000.00
# Cornell University                     $110,000.00
# ...

# %%
region4 = regions.set_index('School Name')

# %%
pd.merge(ivies4,region4,left_index = True, right_index = True)
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
# Cornell University          Ivy League            $60,300.00
# Dartmouth College           Ivy League            $58,000.00
# Harvard University          Ivy League            $63,400.00
# Princeton University        Ivy League            $66,500.00
# University of Pennsylvania  Ivy League            $60,900.00
# Yale University             Ivy League            $59,100.00
#
#                            Mid-Career Median Salary        Region
# School Name
# Brown University                       $109,000.00   Northeastern
# Columbia University                    $107,000.00   Northeastern
# Cornell University                     $110,000.00   Northeastern
# Dartmouth College                      $134,000.00   Northeastern
# ...

# %%
regions
# Out:
#                                       School Name        Region
# 0     Massachusetts Institute of Technology (MIT)  Northeastern
# 1        California Institute of Technology (CIT)    California
# 2                             Harvey Mudd College    California
# 3    Polytechnic University of New York, Brooklyn  Northeastern
# 4                                    Cooper Union  Northeastern
# ..                                            ...           ...
# 264                  Austin Peay State University      Southern
# 265                    Pittsburg State University    Midwestern
# 266                      Southern Utah University       Western
# 267           Montana State University - Billings       Western
# 268                  Black Hills State University    Midwestern
#
# [269 rows x 2 columns]

# %%
pd.merge(ivies4,regions,left_index=True,right_on='School Name')
# Out:
#    School Type Starting Median Salary Mid-Career Median Salary  \
# 86  Ivy League            $58,000.00              $134,000.00
# 87  Ivy League            $66,500.00              $131,000.00
# 88  Ivy League            $59,100.00              $126,000.00
# 89  Ivy League            $63,400.00              $124,000.00
# 90  Ivy League            $60,900.00              $120,000.00
# 91  Ivy League            $60,300.00              $110,000.00
# 92  Ivy League            $56,200.00              $109,000.00
# 93  Ivy League            $59,400.00              $107,000.00
#
#                    School Name        Region
# 86           Dartmouth College  Northeastern
# 87        Princeton University  Northeastern
# 88             Yale University  Northeastern
# 89          Harvard University  Northeastern
# 90  University of Pennsylvania  Northeastern
# 91          Cornell University  Northeastern
# 92            Brown University  Northeastern
# ...

# %%
ivies4.join(region4)
# Out:
#                            School Type Starting Median Salary  \
# School Name
# Brown University            Ivy League            $56,200.00
# Columbia University         Ivy League            $59,400.00
# Cornell University          Ivy League            $60,300.00
# Dartmouth College           Ivy League            $58,000.00
# Harvard University          Ivy League            $63,400.00
# Princeton University        Ivy League            $66,500.00
# University of Pennsylvania  Ivy League            $60,900.00
# Yale University             Ivy League            $59,100.00
#
#                            Mid-Career Median Salary        Region
# School Name
# Brown University                       $109,000.00   Northeastern
# Columbia University                    $107,000.00   Northeastern
# Cornell University                     $110,000.00   Northeastern
# Dartmouth College                      $134,000.00   Northeastern
# ...

# %%
ivies.join(region4,on='School Name')
# Out:
#                   School Name School Type Starting Median Salary  \
# 0           Dartmouth College  Ivy League            $58,000.00
# 1        Princeton University  Ivy League            $66,500.00
# 2             Yale University  Ivy League            $59,100.00
# 3          Harvard University  Ivy League            $63,400.00
# 4  University of Pennsylvania  Ivy League            $60,900.00
# 5          Cornell University  Ivy League            $60,300.00
# 6            Brown University  Ivy League            $56,200.00
# 7         Columbia University  Ivy League            $59,400.00
#
#   Mid-Career Median Salary        Region
# 0             $134,000.00   Northeastern
# 1             $131,000.00   Northeastern
# 2             $126,000.00   Northeastern
# 3             $124,000.00   Northeastern
# 4             $120,000.00   Northeastern
# 5             $110,000.00   Northeastern
# 6             $109,000.00   Northeastern
# 7             $107,000.00   Northeastern

# %%
dfm = pd.merge(liberal,regions.drop_duplicates(subset='School Name',keep='first'),how='inner',on='School Name')

# %%
dfm
# Out:
#                                       School Name   School Type  \
# 0                             Bucknell University  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 2                                 Amherst College  Liberal Arts
# 3                               Lafayette College  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 6                              Occidental College  Liberal Arts
# 7                   Washington and Lee University  Liberal Arts
# 8                              Swarthmore College  Liberal Arts
# 9                                Davidson College  Liberal Arts
# 10                               Carleton College  Liberal Arts
# 11                               Williams College  Liberal Arts
# 12                                 Pomona College  Liberal Arts
# 13  Wesleyan University (Middletown, Connecticut)  Liberal Arts
# ...

# %%
dfm['Region'].value_counts()
# Out:
# Northeastern    25
# Midwestern       8
# Western          7
# Southern         4
# California       3
# Name: Region, dtype: int64

# %%
income.set_index('school_name',inplace=True)

# %%
pd.merge(dfm,income,left_on = 'School Name',right_index=True)
# Out:
#                                       School Name   School Type  \
# 0                             Bucknell University  Liberal Arts
# 1                              Colgate University  Liberal Arts
# 2                                 Amherst College  Liberal Arts
# 3                               Lafayette College  Liberal Arts
# 4                                 Bowdoin College  Liberal Arts
# 5                       College of the Holy Cross  Liberal Arts
# 6                              Occidental College  Liberal Arts
# 7                   Washington and Lee University  Liberal Arts
# 8                              Swarthmore College  Liberal Arts
# 9                                Davidson College  Liberal Arts
# 10                               Carleton College  Liberal Arts
# 11                               Williams College  Liberal Arts
# 12                                 Pomona College  Liberal Arts
# 13  Wesleyan University (Middletown, Connecticut)  Liberal Arts
# ...

# %%
pd.merge(dfm,income,left_on = 'School Name',right_index=True,how='outer').sort_values('School Name')
# Out:
#                                 School Name   School Type  \
# 2.0                         Amherst College  Liberal Arts
# NaN            Appalachian State University           NaN
# NaN          Arizona State University (ASU)           NaN
# NaN          Arizona State University (ASU)           NaN
# NaN         Arkansas State University (ASU)           NaN
# ...                                     ...           ...
# 36.0                        Whitman College  Liberal Arts
# 11.0                       Williams College  Liberal Arts
# 39.0                  Wittenberg University  Liberal Arts
# NaN   Worcester Polytechnic Institute (WPI)           NaN
# NaN                         Yale University           NaN
#
#      Starting Median Salary Mid-Career Median Salary        Region  \
# 2.0             $54,500.00              $107,000.00   Northeastern
# NaN                     NaN                      NaN           NaN
# ...

# %%
income.index.unique()
# Out:
# Index(['Massachusetts Institute of Technology (MIT)',
#        'California Institute of Technology (CIT)', 'Harvey Mudd College',
#        'Polytechnic University of New York, Brooklyn', 'Cooper Union',
#        'Worcester Polytechnic Institute (WPI)',
#        'Carnegie Mellon University (CMU)',
#        'Rensselaer Polytechnic Institute (RPI)',
#        'Georgia Institute of Technology', 'Colorado School of Mines',
#        ...
#        'Arkansas State University (ASU)', 'Kent State University',
#        'Tarleton State University (TSU)',
#        'University of Wisconsin (UW) - Green Bay', 'Morehead State University',
#        'Austin Peay State University', 'Pittsburg State University',
#        'Southern Utah University', 'Montana State University - Billings',
#        'Black Hills State University'],
#       dtype='object', name='school_name', length=249)
