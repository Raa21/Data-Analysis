# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns',None)

# %%
players = pd.read_csv("C:/Users/rajen/Data Analysis/soccer.csv")

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
df2 = players.drop([2,10,21],axis = 0).drop(['market_value'],axis = 1)

# %%
df2.nationality.isna()
# Out:
# 0      False
# 1      False
# 3      False
# 4      False
# 5      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: nationality, Length: 462, dtype: bool

# %%
df2[df2.nationality.isna()]
# Out:
# Empty DataFrame
# Columns: [name, club, age, position, position_cat, page_views, fpl_value, fpl_sel, fpl_points, region, nationality, new_foreign, age_cat, club_id, big_club, new_signing]
# Index: []

# %%
df2.nationality.nunique()
# Out:
# 61

# %%
players.drop(index=[2,10,21],columns ='market_value').head(25)
# Out:
#                        name     club  age position  position_cat  page_views  \
# 0            Alexis Sanchez  Arsenal   28       LW             1        4329
# 1                Mesut Ozil  Arsenal   28       AM             1        4395
# 3              Theo Walcott  Arsenal   28       RW             1        2393
# 4         Laurent Koscielny  Arsenal   31       CB             3         912
# 5           Hector Bellerin  Arsenal   22       RB             3        1675
# 6            Olivier Giroud  Arsenal   30       CF             1        2230
# 7             Nacho Monreal  Arsenal   31       LB             3         555
# 8          Shkodran Mustafi  Arsenal   25       CB             3        1877
# 9                Alex Iwobi  Arsenal   21       LW             1        1812
# 11             Granit Xhaka  Arsenal   24       DM             2        1815
# 12  Alex Oxlade-Chamberlain  Arsenal   23       RM             2        1519
# ...

# %%
df2.drop_duplicates(subset = ['age','position','club'],keep = 'first')
# Out:
#                     name      club  age position  position_cat  page_views  \
# 0         Alexis Sanchez   Arsenal   28       LW             1        4329
# 1             Mesut Ozil   Arsenal   28       AM             1        4395
# 3           Theo Walcott   Arsenal   28       RW             1        2393
# 4      Laurent Koscielny   Arsenal   31       CB             3         912
# 5        Hector Bellerin   Arsenal   22       RB             3        1675
# ..                   ...       ...  ...      ...           ...         ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2         288
# 461       Arthur Masuaku  West+Ham   23       LB             3         199
# 462            Sam Byram  West+Ham   23       RB             3         198
# 463      Ashley Fletcher  West+Ham   21       CF             1         412
# 464         Diafra Sakho  West+Ham   27       CF             1         214
#
# ...

# %%
df2.shape
# Out:
# (462, 16)

# %%
df2.drop_duplicates(subset = ['age','position','club'],keep = 'first').loc[:,['age','position']]
# Out:
#      age position
# 0     28       LW
# 1     28       AM
# 3     28       RW
# 4     31       CB
# 5     22       RB
# ..   ...      ...
# 460   21       CM
# 461   23       LB
# 462   23       RB
# 463   21       CF
# 464   27       CF
#
# [433 rows x 2 columns]

# %%
players.agg('mean')
# Out:
# C:\Users\rajen\AppData\Local\Temp\ipykernel_3828\3820880281.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   players.agg('mean')
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.agg('min')
# Out:
# C:\Users\rajen\AppData\Local\Temp\ipykernel_3828\2396883812.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   players.agg('min')
# name            Aaron Cresswell
# club                    Arsenal
# age                          17
# position_cat                  1
# market_value               0.05
# page_views                    3
# fpl_value                   4.0
# fpl_sel                   0.00%
# fpl_points                    0
# region                        1
# nationality             Algeria
# new_foreign                   0
# age_cat                       1
# club_id                       1
# big_club                      0
# new_signing                   0
# dtype: object

# %%
ord('b')
# Out:
# 98

# %%
ord('B')
# Out:
# 66

# %%
'B'<'b'
# Out:
# True

# %%
players.agg('max',numeric_only =True)
# Out:
# age               38.0
# position_cat       4.0
# market_value      75.0
# page_views      7664.0
# fpl_value         12.5
# fpl_points       264.0
# region             4.0
# new_foreign        1.0
# age_cat            6.0
# club_id           20.0
# big_club           1.0
# new_signing        1.0
# dtype: float64

# %%
players.agg(['min','max','mean'],numeric_only = True)
# Out:
# C:\Users\rajen\AppData\Local\Temp\ipykernel_3828\59561731.py:1: FutureWarning: ['name', 'club', 'position', 'fpl_sel', 'nationality'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   players.agg(['min','max','mean'],numeric_only = True)
#                     name      club        age  position_cat  market_value  \
# min      Aaron Cresswell   Arsenal  17.000000      1.000000      0.050000
# max   Åukasz FabiaÅ„ski  West+Ham  38.000000      4.000000     75.000000
# mean                 NaN       NaN  26.776344      2.178495     11.125649
#
#        page_views  fpl_value fpl_sel  fpl_points    region nationality  \
# min      3.000000   4.000000   0.00%    0.000000  1.000000     Algeria
# max   7664.000000  12.500000   9.70%  264.000000  4.000000       Wales
# mean   771.546237   5.450538     NaN   57.544086  1.989247         NaN
#
# ...

# %%
players.select_dtypes(np.number).agg(['min','max','mean'])
# Out:
#             age  position_cat  market_value   page_views  fpl_value  \
# min   17.000000      1.000000      0.050000     3.000000   4.000000
# max   38.000000      4.000000     75.000000  7664.000000  12.500000
# mean  26.776344      2.178495     11.125649   771.546237   5.450538
#
#       fpl_points    region  new_foreign   age_cat    club_id  big_club  \
# min     0.000000  1.000000     0.000000  1.000000   1.000000  0.000000
# max   264.000000  4.000000     1.000000  6.000000  20.000000  1.000000
# mean   57.544086  1.989247     0.034409  3.195699  10.253763  0.309677
#
#       new_signing
# min      0.000000
# max      1.000000
# mean     0.144086

# %%
players.loc['market_value','fpl_value']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 players.loc['market_value','fpl_value']
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
# ...

# %%
players.loc[:,['market_value','fpl_points']]
# Out:
#      market_value  fpl_points
# 0            65.0         264
# 1            50.0         167
# 2             7.0         134
# 3            20.0         122
# 4            22.0         121
# ..            ...         ...
# 460           5.0          38
# 461           7.0          34
# 462           4.5          29
# 463           1.0          16
# 464          10.0          12
#
# [465 rows x 2 columns]

# %%
players.loc[:,['market_value','fpl_value']]*1.051
# Out:
#      market_value  fpl_value
# 0         68.3150    12.6120
# 1         52.5500     9.9845
# 2          7.3570     5.7805
# 3         21.0200     7.8825
# 4         23.1220     6.3060
# ..            ...        ...
# 460        5.2550     4.7295
# 461        7.3570     4.7295
# 462        4.7295     4.7295
# 463        1.0510     4.7295
# 464       10.5100     5.7805
#
# [465 rows x 2 columns]

# %%
players.loc[:,['market_value','fpl_value']].transform(lambda x: x*1.051)
# Out:
#      market_value  fpl_value
# 0         68.3150    12.6120
# 1         52.5500     9.9845
# 2          7.3570     5.7805
# 3         21.0200     7.8825
# 4         23.1220     6.3060
# ..            ...        ...
# 460        5.2550     4.7295
# 461        7.3570     4.7295
# 462        4.7295     4.7295
# 463        1.0510     4.7295
# 464       10.5100     5.7805
#
# [465 rows x 2 columns]

# %%
#-aplly a random string capitalisation method
#-to a squence of values and
#-return the transform sequence

# %%
from random import choice

# %%
def random_choice(x):
    func = [x.str.upper,x.str.title,x.str.lower,x.str.swapcase]
    return choice(func)()

# %%
df3 = players.select_dtypes(include = 'object')

# %%
df3
# Out:
#                     name      club position fpl_sel     nationality
# 0         Alexis Sanchez   Arsenal       LW  17.10%           Chile
# 1             Mesut Ozil   Arsenal       AM   5.60%         Germany
# 2              Petr Cech   Arsenal       GK   5.90%  Czech Republic
# 3           Theo Walcott   Arsenal       RW   1.50%         England
# 4      Laurent Koscielny   Arsenal       CB   0.70%          France
# ..                   ...       ...      ...     ...             ...
# 460  Edimilson Fernandes  West+Ham       CM   0.40%     Switzerland
# 461       Arthur Masuaku  West+Ham       LB   0.20%        Congo DR
# 462            Sam Byram  West+Ham       RB   0.30%         England
# 463      Ashley Fletcher  West+Ham       CF   5.90%         England
# 464         Diafra Sakho  West+Ham       CF   0.10%         Senegal
#
# [465 rows x 5 columns]

# %%
for i in range(4):
    print(df3.transform(random_choice).head())
# Out:
#                 name     club position fpl_sel     nationality
# 0     Alexis Sanchez  aRSENAL       LW  17.10%           chile
# 1         Mesut Ozil  aRSENAL       AM   5.60%         germany
# 2          Petr Cech  aRSENAL       GK   5.90%  czech republic
# 3       Theo Walcott  aRSENAL       RW   1.50%         england
# 4  Laurent Koscielny  aRSENAL       CB   0.70%          france
#                 name     club position fpl_sel     nationality
# 0     Alexis Sanchez  aRSENAL       lw  17.10%           cHILE
# 1         Mesut Ozil  aRSENAL       am   5.60%         gERMANY
# 2          Petr Cech  aRSENAL       gk   5.90%  cZECH rEPUBLIC
# 3       Theo Walcott  aRSENAL       rw   1.50%         eNGLAND
# 4  Laurent Koscielny  aRSENAL       cb   0.70%          fRANCE
#                 name     club position fpl_sel     nationality
# 0     ALEXIS SANCHEZ  arsenal       lw  17.10%           CHILE
# 1         MESUT OZIL  arsenal       am   5.60%         GERMANY
# ...

# %%
players.apply('mean',numeric_only=True)
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.info(verbose=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465 entries, 0 to 464
# Columns: 17 entries, name to new_signing
# dtypes: float64(2), int64(10), object(5)
# memory usage: 61.9+ KB

# %%
def und(x):
    if x.dtype == 'float64':
        return round(x)
    
    return x

# %%
players.select_dtypes('float64')
# Out:
#      market_value  fpl_value
# 0            65.0       12.0
# 1            50.0        9.5
# 2             7.0        5.5
# 3            20.0        7.5
# 4            22.0        6.0
# ..            ...        ...
# 460           5.0        4.5
# 461           7.0        4.5
# 462           4.5        4.5
# 463           1.0        4.5
# 464          10.0        5.5
#
# [465 rows x 2 columns]

# %%
players.select_dtypes('float64').apply(und)
# Out:
#      market_value  fpl_value
# 0            65.0       12.0
# 1            50.0       10.0
# 2             7.0        6.0
# 3            20.0        8.0
# 4            22.0        6.0
# ..            ...        ...
# 460           5.0        4.0
# 461           7.0        4.0
# 462           4.0        4.0
# 463           1.0        4.0
# 464          10.0        6.0
#
# [465 rows x 2 columns]

# %%
players.apply('mean',numeric_only=True)
# Out:
# age              26.776344
# position_cat      2.178495
# market_value     11.125649
# page_views      771.546237
# fpl_value         5.450538
# fpl_points       57.544086
# region            1.989247
# new_foreign       0.034409
# age_cat           3.195699
# club_id          10.253763
# big_club          0.309677
# new_signing       0.144086
# dtype: float64

# %%
players.apply('mean',axis = 1,numeric_only=True)
# Out:
# 0      392.333333
# 1      388.208333
# 2      143.708333
# 3      214.875000
# 4       91.916667
#           ...
# 460     31.875000
# 461     24.791667
# 462     23.750000
# 463     39.875000
# 464     24.708333
# Length: 465, dtype: float64

# %%
players.loc[3,:]
# Out:
# name            Theo Walcott
# club                 Arsenal
# age                       28
# position                  RW
# position_cat               1
# market_value            20.0
# page_views              2393
# fpl_value                7.5
# fpl_sel                1.50%
# fpl_points               122
# region                     1
# nationality          England
# new_foreign                0
# age_cat                    4
# club_id                    1
# big_club                   1
# new_signing                0
# Name: 3, dtype: object

# %%
players.loc[3,[dtypes != object for dtypes in players.dtypes]].mean()
# Out:
# 214.875

# %%
from datetime import datetime

# %%
infla = 1.85

# %%
mini_df = players.loc[:,['market_value','fpl_value']]

# %%
mini_df * infla
# Out:
#      market_value  fpl_value
# 0         120.250     22.200
# 1          92.500     17.575
# 2          12.950     10.175
# 3          37.000     13.875
# 4          40.700     11.100
# ..            ...        ...
# 460         9.250      8.325
# 461        12.950      8.325
# 462         8.325      8.325
# 463         1.850      8.325
# 464        18.500     10.175
#
# [465 rows x 2 columns]

# %%
counter = 0

def log_n_transform(x):
    global counter
    counter += 1
    if counter % 100 == 0:
        print(f"It is {datetime.now()} and I just adjusted the {counter}th value")
        
    return x*infla

# %%
mini_df.applymap(log_n_transform)
# Out:
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 100th value
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 200th value
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 300th value
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 400th value
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 500th value
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 600th value
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 700th value
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 800th value
# It is 2022-06-23 19:17:04.587712 and I just adjusted the 900th value
#      market_value  fpl_value
# 0         120.250     22.200
# 1          92.500     17.575
# 2          12.950     10.175
# 3          37.000     13.875
# 4          40.700     11.100
# ..            ...        ...
# 460         9.250      8.325
# 461        12.950      8.325
# 462         8.325      8.325
# 463         1.850      8.325
# ...

# %%
def stat_pl(x):
    if x < 220:
        return 'relatively unknown'
    elif (x<600):
        return 'kind of popular'
    elif (x<2000):
        return 'popular'
    else:
        return 'super-popular'

# %%
players.loc[:,['page_views']].applymap(stat_pl)
# Out:
#              page_views
# 0       kind of popular
# 1       kind of popular
# 2       kind of popular
# 3       kind of popular
# 4       kind of popular
# ..                  ...
# 460     kind of popular
# 461  relatively unknown
# 462  relatively unknown
# 463     kind of popular
# 464  relatively unknown
#
# [465 rows x 1 columns]

# %%
def stat_pl2(x):
    if players.columns.all == 'page_views':
        if x < 220:
            return 'relatively unknown'
        if  x<600:
            return 'kind of popular'
        if x<2000:
            return 'popular'
        else:
            return 'super-popular'
        
    return x

# %%
players.apply(stat_pl2)
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.columns.all
# Out:
# <bound method Index.all of Index(['name', 'club', 'age', 'position', 'position_cat', 'market_value',
#        'page_views', 'fpl_value', 'fpl_sel', 'fpl_points', 'region',
#        'nationality', 'new_foreign', 'age_cat', 'club_id', 'big_club',
#        'new_signing'],
#       dtype='object')>

# %%
players.page_views.apply(stat_pl)
# Out:
# 0           super-popular
# 1           super-popular
# 2                 popular
# 3           super-popular
# 4                 popular
#               ...
# 460       kind of popular
# 461    relatively unknown
# 462    relatively unknown
# 463       kind of popular
# 464    relatively unknown
# Name: page_views, Length: 465, dtype: object

# %%
players[columns = {'popularity':players.page_views.apply(stat_pl)}]
# Out:
#   Input In [141]
#     players[columns = {'popularity':players.page_views.apply(stat_pl)}]
#                     ^
# SyntaxError: invalid syntax

# %%
players.loc[:,['page_views']].applymap(stat_pl) == 'super-popular'
# Out:
#      page_views
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# ..          ...
# 460       False
# 461       False
# 462       False
# 463       False
# 464       False
#
# [465 rows x 1 columns]

# %%
stat_pl(700)
# Out:
# 'popular'

# %%
players['popularity'] = players.page_views.apply(stat_pl)

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.popularity == 'super-popular'
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4      False
#        ...
# 460    False
# 461    False
# 462    False
# 463    False
# 464    False
# Name: popularity, Length: 465, dtype: bool

# %%
players[players.popularity == 'super-popular']
# Out:
#                       name               club  age position  position_cat  \
# 0           Alexis Sanchez            Arsenal   28       LW             1
# 1               Mesut Ozil            Arsenal   28       AM             1
# 3             Theo Walcott            Arsenal   28       RW             1
# 6           Olivier Giroud            Arsenal   30       CF             1
# 24             Lucas Perez            Arsenal   28       CF             1
# 33           Jermain Defoe        Bournemouth   34       CF             1
# 96             Eden Hazard            Chelsea   26       LW             1
# 97             Diego Costa            Chelsea   28       CF             1
# 99   Marcos Alonso Mendoza            Chelsea   26       LB             3
# 103             David Luiz            Chelsea   30       CB             3
# 104          Cesc Fabregas            Chelsea   30       CM             2
# 106           Victor Moses            Chelsea   26       RM             2
# ...

# %%
players.popularity.value_counts()
# Out:
# kind of popular       170
# popular               143
# relatively unknown    115
# super-popular          37
# Name: popularity, dtype: int64

# %%
players[players.popularity == 'super-popular'].name.size
# Out:
# 37

# %%
players.iloc[3,3] = 'RW'

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players.at[2,'position'] = 'GK'

# %%
players.position.unique()
# Out:
# array(['LW', 'AM', 'GK', 'RW', 'CB', 'RB', 'CF', 'LB', 'DM', 'RM', 'CM',
#        nan, 'SS', 'LM'], dtype=object)

# %%
players.iat[2,6] = 2001

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
players['MVtoFPL'] = 1

# %%
players =players.drop([3,4],axis = 1)

# %%
players['MVtoFPL'] = players['market_value']/players['fpl_value']

# %%
players
# Out:
#                     name      club  age position  position_cat  market_value  \
# 0         Alexis Sanchez   Arsenal   28       LW             1          65.0
# 1             Mesut Ozil   Arsenal   28       AM             1          50.0
# 2              Petr Cech   Arsenal   35       GK             4           7.0
# 3           Theo Walcott   Arsenal   28       RW             1          20.0
# 4      Laurent Koscielny   Arsenal   31       CB             3          22.0
# ..                   ...       ...  ...      ...           ...           ...
# 460  Edimilson Fernandes  West+Ham   21       CM             2           5.0
# 461       Arthur Masuaku  West+Ham   23       LB             3           7.0
# 462            Sam Byram  West+Ham   23       RB             3           4.5
# 463      Ashley Fletcher  West+Ham   21       CF             1           1.0
# 464         Diafra Sakho  West+Ham   27       CF             1          10.0
#
# ...

# %%
df_mini = players.iloc[:4,1:5]

# %%
df_mini
# Out:
#       club  age position  position_cat
# 0  Arsenal   28       LW             1
# 1  Arsenal   28       AM             1
# 2  Arsenal   35       GK             4
# 3  Arsenal   28       RW             1

# %%
pl_names = pd.Series(['Rpnaldo','Roony','Christian','Bale'])

# %%
df_mini.insert(0,'nicknames',pl_names)

# %%
df_mini
# Out:
#    nicknames     club  age position  position_cat
# 0    Rpnaldo  Arsenal   28       LW             1
# 1      Roony  Arsenal   28       AM             1
# 2  Christian  Arsenal   35       GK             4
# 3       Bale  Arsenal   28       RW             1

# %%
df_mini.assign(career_goals = [12,67,178,49],nationality = ['India','America','French','Spaniard'])
# Out:
#    nicknames     club  age position  position_cat  career_goals nationality
# 0    Rpnaldo  Arsenal   28       LW             1            12       India
# 1      Roony  Arsenal   28       AM             1            67     America
# 2  Christian  Arsenal   35       GK             4           178      French
# 3       Bale  Arsenal   28       RW             1            49    Spaniard

# %%
df_mini.append({
    'nicknames':'Cristiano',
    'club': 'Juventus',
    'age':34,
    'position':'RW',
    'position_cat':1
},ignore_index = True)
# Out:
# C:\Users\rajen\AppData\Local\Temp\ipykernel_9724\1991902912.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_mini.append({
#    nicknames      club  age position  position_cat
# 0    Rpnaldo   Arsenal   28       LW             1
# 1      Roony   Arsenal   28       AM             1
# 2  Christian   Arsenal   35       GK             4
# 3       Bale   Arsenal   28       RW             1
# 4  Cristiano  Juventus   34       RW             1

# %%
other_players = pd.DataFrame({
    'nicknames':['Buffon','Messi'],
    'age':[38,35],
    'club':['Juventus','Barcelona'],
    'position':['GK','LW'],
    'position_cat':[4,2]
},index = [5,6])

# %%
other_players
# Out:
#   nicknames  age       club position  position_cat
# 0    Buffon   38   Juventus       GK             4
# 1     Messi   35  Barcelona       LW             2

# %%
pd.concat([df_mini, other_players],ignore_index = True)
# Out:
#    nicknames       club  age position  position_cat
# 0    Rpnaldo    Arsenal   28       LW             1
# 1      Roony    Arsenal   28       AM             1
# 2  Christian    Arsenal   35       GK             4
# 3       Bale    Arsenal   28       RW             1
# 4     Buffon   Juventus   38       GK             4
# 5      Messi  Barcelona   35       LW             2

# %%
df_mini
# Out:
#    nicknames     club  age position  position_cat
# 0    Rpnaldo  Arsenal   28       LW             1
# 1      Roony  Arsenal   28       AM             1
# 2  Christian  Arsenal   35       GK             4
# 3       Bale  Arsenal   28       RW             1

# %%
df_random = players.sample(4,axis = 0).sample(4,axis =1)

# %%
df_random
# Out:
#      region  position_cat   MVtoFPL position
# 165       1             4  0.062500       GK
# 127       2             3  0.222222       CB
# 328       1             3  0.666667       LB
# 429       1             3  1.200000       RB

# %%
# %%timeit
df_random.assign(nationality=['indian','african','american','french'])
# Out:
# 359 µs ± 55 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
df_random.append({
    'region':2,
    'position_cat':5,
    'MVtoFPL':0.6479,
    'position':'RM'
},ignore_index = True)
# Out:
# C:\Users\rajen\AppData\Local\Temp\ipykernel_9724\1736837071.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_random.append({
#    region  position_cat   MVtoFPL position
# 0       1             4  0.062500       GK
# 1       2             3  0.222222       CB
# 2       1             3  0.666667       LB
# 3       1             3  1.200000       RB
# 4       2             5  0.647900       RM

# %%
df_random
# Out:
#      region  position_cat   MVtoFPL position
# 165       1             4  0.062500       GK
# 127       2             3  0.222222       CB
# 328       1             3  0.666667       LB
# 429       1             3  1.200000       RB

# %%
# %%timeit
df2 = pd.DataFrame({
    'region':2,
    'position_cat':5,
    'MVtoFPL':0.6479,
    'position':'RM'
},index=[0])
pd.concat([df_random,df2],ignore_index=True)
# Out:
# 858 µs ± 65.7 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
df1
# Out:
#    region  position_cat  MVtoFPL position
# 0       2             5   0.6479       RM

# %%
# %%timeit
pd.concat([df_random,df1],ignore_index=True)
# Out:
# 309 µs ± 92.2 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
